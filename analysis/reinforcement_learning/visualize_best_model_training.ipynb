# %%
import numpy as np
from deepsudoku import REPO_PATH
import os
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import tqdm

os.chdir(REPO_PATH)

# %%
df = pd.read_csv("stats/rl_best_model_training.csv",index_col=0)
df = df.rename(columns={"step":"Step", 'eval/avg_winrate':'Winrate %',"run":"Model",'charts/avg_episodic_return':"Avg Return", 'charts/avg_episodic_length':"Avg Length"})
df['Winrate %'] *= 100

plt.figure(figsize=(12,3),)
plt.subplot(1,3,1)

sns.lineplot(df, x = "Step", y = "Avg Return")
plt.subplot(1,3,2)
sns.lineplot(df, x = "Step", y = "Avg Length")
plt.subplot(1,3,3)
sns.lineplot(df, x = "Step", y = "Winrate %")
plt.tight_layout()
plt.savefig("imgs/rl_best_model_training.jpg", bbox_inches='tight', dpi=300)
plt.show()
