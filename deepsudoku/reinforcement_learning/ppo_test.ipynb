# %%
import gymnasium as gym
import tensorflow as tf
import numpy as np
import random
# Out:
# 2023-08-20 19:06:43.357757: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
NUM_ENVS = 5
STEPS_PER_TRAJECTORY = 50

GAMMA = 0.99
LAMBDA = 0.95
CLIP_RATIO = 0.2
MAX_GRAD_NORM = 0.5

TRAIN_EPOCHS = 2500
NUM_UPDATE_EPOCHS = 1
MINIBATCH_SIZE = 50

# Adam learning rate (Implementation Detail 4)
# NOTE: we changed this from 0.00025 to 0.005
LEARNING_RATE_START = 0.005
LEARNING_RATE_DECAY_PER_EPOCH = LEARNING_RATE_START/TRAIN_EPOCHS

EPSILON = 0.2
EPSILON_DECAY_FACTOR = 0.999

# %%
# Implementation Detail 2: Orthogonal Initialization of hidden weights and constant initialization of biases and output weights
# Biases seem to be 0 by default in Keras
hidden_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=np.sqrt(2))
pol_out_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=0.01)
val_out_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=1)

# Define the models
def create_policy_model():
    inputs = tf.keras.Input(shape=(8,))
    x = tf.keras.layers.Dense(32, activation="tanh", kernel_initializer=hidden_ortho_init())(inputs)
    x = tf.keras.layers.Dense(32, activation="tanh", kernel_initializer=hidden_ortho_init())(x)
    outputs = tf.keras.layers.Dense(4, activation="log_softmax", kernel_initializer=pol_out_ortho_init())(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="pi")
    return model

def create_value_function_model():
    inputs = tf.keras.Input(shape=(8,))
    x = tf.keras.layers.Dense(32, activation="relu", kernel_initializer=hidden_ortho_init())(inputs)
    #x = tf.keras.layers.Dense(32, activation="relu", kernel_initializer=hidden_ortho_init())(x)
    outputs = tf.keras.layers.Dense(1, activation="linear", kernel_initializer=val_out_ortho_init())(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="V")
    return model

# Implementation Detail 3: The Adam Optimizers Epsilon and beta parameters are already fine by default
value_optimizer = tf.keras.optimizers.Adam(learning_rate = LEARNING_RATE_START)
pi_optimizer = tf.keras.optimizers.Adam(learning_rate = LEARNING_RATE_START)
# Out:
# 2023-08-20 19:06:46.297578: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
class Environment:
    def __init__(self, NUM_ENVS):
        self.num_envs = NUM_ENVS
        #self.envs = envs = gym.vector.make('CartPole-v1', num_envs=NUM_ENVS)
        self.envs = envs = gym.vector.make('LunarLander-v2', num_envs=NUM_ENVS)
        self.current_state, _ = self.envs.reset()

    def sample(self, model, epsilon=0.2):
        old_observation = self.current_state
        q_values = model(self.current_state) #get q values for current state
        #Q_values are logprobs, we exp them to sample
        probs = np.exp(q_values)
        action = [np.random.choice(list(range(self.envs.single_action_space.n)), p=prob, size=1)[0] for prob in probs]
        action = [self.envs.single_action_space.sample() if random.random() < epsilon else a for a in action] #choose epsilon greedy
        new_observation, reward, terminated, _, _ = self.envs.step(action)

        self.current_state = new_observation #update current state after environment did step
        return (old_observation, action, reward, new_observation, terminated)
    
    def collect_trajectories(self, model, length, epsilon = 0.2):
        old_obs, act, rew, new_obs, term = self.sample(model, epsilon=epsilon)
        data = {"observations": np.expand_dims(old_obs, axis=1), 
                "actions": act, 
                "rewards": rew, 
                "terminateds": term}
        for i in range(length-1):
            old_obs, act, rew, new_obs, term = self.sample(model, epsilon=epsilon)
            data["observations"] = np.column_stack((data["observations"], np.expand_dims(old_obs, axis=1)))
            data["actions"] = np.column_stack((data["actions"], act))
            data["rewards"] = np.column_stack((data["rewards"], rew))
            data["terminateds"] = np.column_stack((data["terminateds"], term))
        return data, new_obs

# %%
#TODO:
# Implementation Details 10,(12)


# We use vectorized environments (Implementation Detail 1)
env = Environment(NUM_ENVS)

########################################################################################################
# 1: Input: initial policy parameters θ_0, initial value function parameters Φ_o
# We use seperate MLP networks for policy and value function (Implementation Detail 13)
pi = create_policy_model() # initial policy
V = create_value_function_model() # initial value function
########################################################################################################

kl_approx = 0
########################################################################################################
# 2: for k = 0, 1, 2, ... do
for k in range(TRAIN_EPOCHS):
    print("epoch: ", k, " ; KL: ", kl_approx, " ; LR: ", pi_optimizer.learning_rate.numpy(), " ; EPSILON: ", EPSILON)
    #print("Gathering trajectories")
########################################################################################################


    ########################################################################################################
    # 3: Collect set of trajectories D_k = {τ_i} by running policy π_k = pi(θ_k) in the environment.
    print("Collection")
    D, ensuing_observation = env.collect_trajectories(pi, STEPS_PER_TRAJECTORY, epsilon=EPSILON)
    #D = {"observations": [environment][timestep], 
    #     "actions": [environment][timestep], 
    #     "rewards": [environment][timestep], 
    #     "terminateds": [environment][timestep]] }
    ########################################################################################################


    ########################################################################################################
    # 4: Compute rewards-to-go R̂_t
    # 5: Compute advantage estimates, Â_t (using any method of advantage estimation) based on the current value function V_Φ_k
    # We use Generalized Advantage Estimation, since spinning up uses it too (Implementation Detail 5)
    # Accordingly, we also do not really implement rewards-to-go, but use a TD(lambda) estimation where rewards_to_go = advantages + values
    # (derived from advantages = rewards_to_go - values)
    #
    #TODO: Can be made more efficient?
    values = np.zeros_like(D["rewards"], dtype=np.float32)
    for env_ind in range(len(D["observations"])):
        values[env_ind] = tf.reshape(V(D["observations"][env_ind]), (-1))
    #
    advantages = np.zeros_like(D["rewards"], dtype=np.float32)
    # Most environments will not be terminated at the last step. We estimate the rest-reward after the last step
    # as the value function for the next observation.
    advantages[:,-1] = D["rewards"][:,-1] + GAMMA * tf.reshape(V(ensuing_observation), (-1)) * (1-D["terminateds"][:,-1]) - values[:,-1]
    for ind in reversed(range(STEPS_PER_TRAJECTORY-1)):
        # The GAE(t) = delta + (GAMMA*LAMBDA)*GAE(t+1) with delta = r_t + gamma * V(s_t+1) - V(s_t)
        # If a state s_t is terminal, V(s_t+1) should be disregarded, since the next state does not belong to the episode anymore
        delta = D["rewards"][:,ind] + GAMMA * values[:,ind+1] * (1-D["terminateds"][:,ind]) - values[:,ind]
        advantages[:,ind] = delta + GAMMA*LAMBDA*advantages[:,ind+1] * (1-D["terminateds"][:,ind])
    #
    # flatten data
    advantages = np.reshape(advantages, (-1, *advantages.shape[2:]))
    values = np.reshape(values, (-1, *values.shape[2:]))
    for key, val in D.items():
        D[key] = np.reshape(val, (-1, *val.shape[2:]))
    #
    rewards_to_go = advantages + values
    ########################################################################################################

    # Collect old_logits without gradientTaping for taking the ratio later
    old_logits = tf.gather(pi(D["observations"]), D["actions"], batch_dims=1)

    print("Tapework")

    # We minibatch for increasing the efficiency of the gradient ascent (PPO-implementation details nr. 6)
    batch_size = D["observations"].shape[0]
    batch_inds = np.arange(batch_size)
    for update_epoch in range(NUM_UPDATE_EPOCHS):
        np.random.shuffle(batch_inds)
        for minibatch_start in range(0, batch_size, MINIBATCH_SIZE):
            minibatch_end = min(minibatch_start + MINIBATCH_SIZE, batch_size-1)
            minibatch_inds = batch_inds[minibatch_start:minibatch_end]

            mb_obs = D["observations"][minibatch_inds]
            mb_acts = D["actions"][minibatch_inds]
            mb_old_logits = tf.gather(old_logits, minibatch_inds)
            mb_advantages = tf.gather(advantages, minibatch_inds)
            # zero center advantages (Implementation Detail 7)
            mb_advantages = (mb_advantages - tf.reduce_mean(mb_advantages)) / (tf.math.reduce_std(mb_advantages) + 1e-8)

            ########################################################################################################
            # 6: Update the policy by maximizing the PPO-Clip objective
            with tf.GradientTape() as pi_tape:
                new_logits = tf.gather(pi(mb_obs), mb_acts, batch_dims=1)
                logratios = new_logits - mb_old_logits
                ratios = tf.math.exp(logratios)
                surrogate_objective1 = ratios * mb_advantages
                # Implementation Detail 8: clip surrogate objective
                surrogate_objective2 = tf.clip_by_value(ratios, 1 - CLIP_RATIO, 1 + CLIP_RATIO) * mb_advantages
                pi_loss = -tf.reduce_mean(tf.minimum(surrogate_objective1, surrogate_objective2))
            pi_gradients = pi_tape.gradient(pi_loss, pi.trainable_variables) #get
            # Implementation Detail 11: clip gradients
            pi_gradients, _ = tf.clip_by_global_norm(pi_gradients, MAX_GRAD_NORM)
            pi_optimizer.apply_gradients(zip(pi_gradients, pi.trainable_variables)) #and apply gradients
            ########################################################################################################

            # Implementation Detail 12: Implementing KL divergence as debug variable:
            kl_approx = tf.reduce_mean((ratios - 1) - logratios).numpy()

            ########################################################################################################
            # 7: Fit value function by regression on mean-squared error:
            with tf.GradientTape() as val_tape:
                values = V(mb_obs)
                # Implementation Detail 9 not implemented, as it may hurt performance
                value_loss = tf.reduce_mean(tf.square(values - rewards_to_go[minibatch_inds]))
            value_gradients = val_tape.gradient(value_loss, V.trainable_variables) #get
            # Implementation Detail 11 cont.: clip gradients
            value_gradients, _ = tf.clip_by_global_norm(value_gradients, MAX_GRAD_NORM)
            value_optimizer.apply_gradients(zip(value_gradients, V.trainable_variables)) #and apply gradients
            ########################################################################################################
    
    # Anneal Adam Learning Rate (Implementation Detail 4 cont.)
    pi_optimizer.learning_rate.assign(pi_optimizer.learning_rate - LEARNING_RATE_DECAY_PER_EPOCH)
    value_optimizer.learning_rate.assign(value_optimizer.learning_rate - LEARNING_RATE_DECAY_PER_EPOCH)

    EPSILON *= EPSILON_DECAY_FACTOR
# Out:
# epoch:  0  ; KL:  0  ; LR:  0.005  ; EPSILON:  0.2
# Collection
# Tapework
# epoch:  1  ; KL:  0.008653176  ; LR:  0.004998  ; EPSILON:  0.1998
# Collection
# Tapework
# epoch:  2  ; KL:  0.0012509166  ; LR:  0.004996  ; EPSILON:  0.1996002
# Collection
# Tapework
# epoch:  3  ; KL:  0.0009996697  ; LR:  0.004994  ; EPSILON:  0.1994005998
# Collection
# Tapework
# epoch:  4  ; KL:  0.0018109351  ; LR:  0.004992  ; EPSILON:  0.1992011992002
# Collection
# Tapework
# epoch:  5  ; KL:  0.004466929  ; LR:  0.00499  ; EPSILON:  0.1990019980009998
# Collection
# Tapework
# epoch:  6  ; KL:  0.0034710523  ; LR:  0.004988  ; EPSILON:  0.1988029960029988
# Collection
# Tapework
# epoch:  7  ; KL:  0.0050617126  ; LR:  0.004986  ; EPSILON:  0.1986041930069958
# Collection
# Tapework
# epoch:  8  ; KL:  0.0052889306  ; LR:  0.0049839998  ; EPSILON:  0.19840558881398881
# Collection
# Tapework
# epoch:  9  ; KL:  0.004668905  ; LR:  0.0049819998  ; EPSILON:  0.19820718322517483
# Collection
# Tapework
# epoch:  10  ; KL:  0.0046299794  ; LR:  0.0049799997  ; EPSILON:  0.19800897604194967
# Collection
# Tapework
# epoch:  11  ; KL:  0.006774687  ; LR:  0.0049779997  ; EPSILON:  0.19781096706590773
# Collection
# Tapework
# epoch:  12  ; KL:  0.004966866  ; LR:  0.0049759997  ; EPSILON:  0.1976131560988418
# Collection
# Tapework
# epoch:  13  ; KL:  0.0025691122  ; LR:  0.0049739997  ; EPSILON:  0.19741554294274297
# Collection
# Tapework
# epoch:  14  ; KL:  0.0015875028  ; LR:  0.0049719997  ; EPSILON:  0.1972181273998002
# Collection
# Tapework
# epoch:  15  ; KL:  0.0019366  ; LR:  0.0049699997  ; EPSILON:  0.1970209092724004
# Collection
# Tapework
# epoch:  16  ; KL:  0.003824832  ; LR:  0.0049679996  ; EPSILON:  0.196823888363128
# Collection
# Tapework
# epoch:  17  ; KL:  0.0052344995  ; LR:  0.0049659996  ; EPSILON:  0.19662706447476488
# Collection
# Tapework
# epoch:  18  ; KL:  0.019293675  ; LR:  0.0049639996  ; EPSILON:  0.19643043741029012
# Collection
# Tapework
# epoch:  19  ; KL:  0.012498876  ; LR:  0.0049619996  ; EPSILON:  0.19623400697287982
# Collection
# Tapework
# epoch:  20  ; KL:  0.0076954323  ; LR:  0.0049599996  ; EPSILON:  0.19603777296590694
# Collection
# Tapework
# epoch:  21  ; KL:  0.005144294  ; LR:  0.0049579996  ; EPSILON:  0.19584173519294104
# Collection
# Tapework
# epoch:  22  ; KL:  0.0041504162  ; LR:  0.0049559996  ; EPSILON:  0.1956458934577481
# Collection
# Tapework
# epoch:  23  ; KL:  0.0020731646  ; LR:  0.0049539995  ; EPSILON:  0.19545024756429036
# Collection
# Tapework
# epoch:  24  ; KL:  0.012938205  ; LR:  0.0049519995  ; EPSILON:  0.19525479731672607
# Collection
# Tapework
# epoch:  25  ; KL:  0.0069006267  ; LR:  0.0049499995  ; EPSILON:  0.19505954251940935
# Collection
# Tapework
# epoch:  26  ; KL:  0.013345577  ; LR:  0.0049479995  ; EPSILON:  0.19486448297688994
# Collection
# Tapework
# epoch:  27  ; KL:  0.0019262427  ; LR:  0.0049459995  ; EPSILON:  0.19466961849391304
# Collection
# Tapework
# epoch:  28  ; KL:  0.0048382888  ; LR:  0.0049439995  ; EPSILON:  0.19447494887541913
# Collection
# Tapework
# epoch:  29  ; KL:  0.0022786271  ; LR:  0.0049419994  ; EPSILON:  0.1942804739265437
# Collection
# Tapework
# epoch:  30  ; KL:  0.008143941  ; LR:  0.0049399994  ; EPSILON:  0.19408619345261716
# Collection
# Tapework
# epoch:  31  ; KL:  0.0036907068  ; LR:  0.0049379994  ; EPSILON:  0.19389210725916453
# Collection
# Tapework
# epoch:  32  ; KL:  0.002009023  ; LR:  0.0049359994  ; EPSILON:  0.19369821515190536
# Collection
# Tapework
# epoch:  33  ; KL:  0.032416485  ; LR:  0.0049339994  ; EPSILON:  0.19350451693675344
# Collection
# Tapework
# epoch:  34  ; KL:  0.013732192  ; LR:  0.0049319994  ; EPSILON:  0.19331101241981669
# Collection
# Tapework
# epoch:  35  ; KL:  0.014571692  ; LR:  0.0049299994  ; EPSILON:  0.19311770140739687
# Collection
# Tapework
# epoch:  36  ; KL:  0.011272092  ; LR:  0.0049279993  ; EPSILON:  0.19292458370598947
# Collection
# Tapework
# epoch:  37  ; KL:  0.008862728  ; LR:  0.0049259993  ; EPSILON:  0.1927316591222835
# Collection
# Tapework
# epoch:  38  ; KL:  0.013117664  ; LR:  0.0049239993  ; EPSILON:  0.1925389274631612
# Collection
# Tapework
# epoch:  39  ; KL:  0.015169493  ; LR:  0.0049219993  ; EPSILON:  0.19234638853569805
# Collection
# Tapework
# epoch:  40  ; KL:  0.02441798  ; LR:  0.0049199993  ; EPSILON:  0.19215404214716236
# Collection
# Tapework
# epoch:  41  ; KL:  0.0060634515  ; LR:  0.0049179993  ; EPSILON:  0.1919618881050152
# Collection
# Tapework
# epoch:  42  ; KL:  0.01443869  ; LR:  0.0049159992  ; EPSILON:  0.19176992621691016
# Collection
# Tapework
# epoch:  43  ; KL:  0.0041126045  ; LR:  0.0049139992  ; EPSILON:  0.19157815629069325
# Collection
# Tapework
# epoch:  44  ; KL:  0.006014055  ; LR:  0.004911999  ; EPSILON:  0.19138657813440255
# Collection
# Tapework
# epoch:  45  ; KL:  0.0115367975  ; LR:  0.004909999  ; EPSILON:  0.19119519155626816
# Collection
# Tapework
# epoch:  46  ; KL:  0.008208761  ; LR:  0.004907999  ; EPSILON:  0.19100399636471188
# Collection
# Tapework
# epoch:  47  ; KL:  0.0015574461  ; LR:  0.004905999  ; EPSILON:  0.19081299236834717
# Collection
# Tapework
# epoch:  48  ; KL:  0.017175112  ; LR:  0.004903999  ; EPSILON:  0.19062217937597883
# Collection
# Tapework
# epoch:  49  ; KL:  0.029080596  ; LR:  0.004901999  ; EPSILON:  0.19043155719660285
# Collection
# Tapework
# epoch:  50  ; KL:  0.008545562  ; LR:  0.004899999  ; EPSILON:  0.19024112563940623
# Collection
# Tapework
# epoch:  51  ; KL:  0.007951988  ; LR:  0.004897999  ; EPSILON:  0.19005088451376684
# Collection
# Tapework
# epoch:  52  ; KL:  0.029807096  ; LR:  0.004895999  ; EPSILON:  0.18986083362925307
# Collection
# Tapework
# epoch:  53  ; KL:  0.012297694  ; LR:  0.004893999  ; EPSILON:  0.1896709727956238
# Collection
# Tapework
# epoch:  54  ; KL:  0.007635427  ; LR:  0.004891999  ; EPSILON:  0.18948130182282819
# Collection
# Tapework
# epoch:  55  ; KL:  0.007025339  ; LR:  0.004889999  ; EPSILON:  0.18929182052100535
# Collection
# Tapework
# epoch:  56  ; KL:  0.062493134  ; LR:  0.004887999  ; EPSILON:  0.18910252870048436
# Collection
# Tapework
# epoch:  57  ; KL:  0.012330922  ; LR:  0.004885999  ; EPSILON:  0.18891342617178386
# Collection
# Tapework
# epoch:  58  ; KL:  0.0011995799  ; LR:  0.004883999  ; EPSILON:  0.18872451274561208
# Collection
# Tapework
# epoch:  59  ; KL:  0.0042749345  ; LR:  0.004881999  ; EPSILON:  0.18853578823286646
# Collection
# Tapework
# epoch:  60  ; KL:  0.019337272  ; LR:  0.004879999  ; EPSILON:  0.1883472524446336
# Collection
# Tapework
# epoch:  61  ; KL:  0.01358265  ; LR:  0.004877999  ; EPSILON:  0.18815890519218897
# Collection
# Tapework
# epoch:  62  ; KL:  0.004707829  ; LR:  0.004875999  ; EPSILON:  0.18797074628699678
# Collection
# Tapework
# epoch:  63  ; KL:  0.0025999136  ; LR:  0.004873999  ; EPSILON:  0.1877827755407098
# Collection
# Tapework
# epoch:  64  ; KL:  0.002984767  ; LR:  0.004871999  ; EPSILON:  0.18759499276516908
# Collection
# Tapework
# epoch:  65  ; KL:  0.0010690826  ; LR:  0.004869999  ; EPSILON:  0.18740739777240392
# Collection
# Tapework
# epoch:  66  ; KL:  0.0038759788  ; LR:  0.004867999  ; EPSILON:  0.18721999037463152
# Collection
# Tapework
# epoch:  67  ; KL:  0.019845529  ; LR:  0.004865999  ; EPSILON:  0.1870327703842569
# Collection
# Tapework
# epoch:  68  ; KL:  0.008541863  ; LR:  0.004863999  ; EPSILON:  0.18684573761387263
# Collection
# Tapework
# epoch:  69  ; KL:  0.0026692967  ; LR:  0.004861999  ; EPSILON:  0.18665889187625875
# Collection
# Tapework
# epoch:  70  ; KL:  0.00052429433  ; LR:  0.004859999  ; EPSILON:  0.1864722329843825
# Collection
# Tapework
# epoch:  71  ; KL:  0.0047728615  ; LR:  0.004857999  ; EPSILON:  0.18628576075139813
# Collection
# Tapework
# epoch:  72  ; KL:  0.0026062278  ; LR:  0.004855999  ; EPSILON:  0.18609947499064675
# Collection
# Tapework
# epoch:  73  ; KL:  0.0019367015  ; LR:  0.004853999  ; EPSILON:  0.1859133755156561
# Collection
# Tapework
# epoch:  74  ; KL:  0.029286958  ; LR:  0.0048519988  ; EPSILON:  0.18572746214014044
# Collection
# Tapework
# epoch:  75  ; KL:  0.023410153  ; LR:  0.0048499987  ; EPSILON:  0.1855417346780003
# Collection
# Tapework
# epoch:  76  ; KL:  0.010615445  ; LR:  0.0048479987  ; EPSILON:  0.1853561929433223
# Collection
# Tapework
# epoch:  77  ; KL:  0.009547555  ; LR:  0.0048459987  ; EPSILON:  0.185170836750379
# Collection
# Tapework
# epoch:  78  ; KL:  0.0030979842  ; LR:  0.0048439987  ; EPSILON:  0.1849856659136286
# Collection
# Tapework
# epoch:  79  ; KL:  0.01236887  ; LR:  0.0048419987  ; EPSILON:  0.18480068024771498
# Collection
# Tapework
# epoch:  80  ; KL:  0.011354565  ; LR:  0.0048399987  ; EPSILON:  0.18461587956746728
# Collection
# Tapework
# epoch:  81  ; KL:  0.016434148  ; LR:  0.0048379987  ; EPSILON:  0.1844312636878998
# Collection
# Tapework
# epoch:  82  ; KL:  0.003513094  ; LR:  0.0048359986  ; EPSILON:  0.18424683242421191
# Collection
# Tapework
# epoch:  83  ; KL:  0.0013228129  ; LR:  0.0048339986  ; EPSILON:  0.1840625855917877
# Collection
# Tapework
# epoch:  84  ; KL:  0.009277237  ; LR:  0.0048319986  ; EPSILON:  0.18387852300619592
# Collection
# Tapework
# epoch:  85  ; KL:  0.0041441633  ; LR:  0.0048299986  ; EPSILON:  0.18369464448318973
# Collection
# Tapework
# epoch:  86  ; KL:  0.002916339  ; LR:  0.0048279986  ; EPSILON:  0.18351094983870653
# Collection
# Tapework
# epoch:  87  ; KL:  0.0032517095  ; LR:  0.0048259986  ; EPSILON:  0.18332743888886782
# Collection
# Tapework
# epoch:  88  ; KL:  0.021497045  ; LR:  0.0048239985  ; EPSILON:  0.18314411144997894
# Collection
# Tapework
# epoch:  89  ; KL:  0.016347216  ; LR:  0.0048219985  ; EPSILON:  0.18296096733852896
# Collection
# Tapework
# epoch:  90  ; KL:  0.0055943374  ; LR:  0.0048199985  ; EPSILON:  0.18277800637119043
# Collection
# Tapework
# epoch:  91  ; KL:  0.019992322  ; LR:  0.0048179985  ; EPSILON:  0.18259522836481923
# Collection
# Tapework
# epoch:  92  ; KL:  0.02228642  ; LR:  0.0048159985  ; EPSILON:  0.18241263313645442
# Collection
# Tapework
# epoch:  93  ; KL:  0.03719227  ; LR:  0.0048139985  ; EPSILON:  0.18223022050331797
# Collection
# Tapework
# epoch:  94  ; KL:  0.008353311  ; LR:  0.0048119985  ; EPSILON:  0.18204799028281465
# Collection
# Tapework
# epoch:  95  ; KL:  0.026300412  ; LR:  0.0048099984  ; EPSILON:  0.18186594229253183
# Collection
# Tapework
# epoch:  96  ; KL:  0.0041223112  ; LR:  0.0048079984  ; EPSILON:  0.1816840763502393
# Collection
# Tapework
# epoch:  97  ; KL:  0.019590607  ; LR:  0.0048059984  ; EPSILON:  0.18150239227388906
# Collection
# Tapework
# epoch:  98  ; KL:  0.0053859614  ; LR:  0.0048039984  ; EPSILON:  0.18132088988161518
# Collection
# Tapework
# epoch:  99  ; KL:  0.010062667  ; LR:  0.0048019984  ; EPSILON:  0.18113956899173356
# Collection
# Tapework
# epoch:  100  ; KL:  0.020797223  ; LR:  0.0047999984  ; EPSILON:  0.18095842942274182
# Collection
# Tapework
# epoch:  101  ; KL:  0.00091545406  ; LR:  0.0047979984  ; EPSILON:  0.1807774709933191
# Collection
# Tapework
# epoch:  102  ; KL:  0.023584813  ; LR:  0.0047959983  ; EPSILON:  0.18059669352232577
# Collection
# Tapework
# epoch:  103  ; KL:  0.019232567  ; LR:  0.0047939983  ; EPSILON:  0.18041609682880344
# Collection
# Tapework
# epoch:  104  ; KL:  0.003484412  ; LR:  0.0047919983  ; EPSILON:  0.18023568073197463
# Collection
# Tapework
# epoch:  105  ; KL:  0.006709446  ; LR:  0.0047899983  ; EPSILON:  0.18005544505124266
# Collection
# Tapework
# epoch:  106  ; KL:  0.032324087  ; LR:  0.0047879983  ; EPSILON:  0.17987538960619143
# Collection
# Tapework
# epoch:  107  ; KL:  0.015765017  ; LR:  0.0047859983  ; EPSILON:  0.17969551421658522
# Collection
# Tapework
# epoch:  108  ; KL:  0.05829624  ; LR:  0.0047839982  ; EPSILON:  0.17951581870236863
# Collection
# Tapework
# epoch:  109  ; KL:  0.020589283  ; LR:  0.004781998  ; EPSILON:  0.17933630288366625
# Collection
# Tapework
# epoch:  110  ; KL:  0.003982463  ; LR:  0.004779998  ; EPSILON:  0.1791569665807826
# Collection
# Tapework
# epoch:  111  ; KL:  0.011862557  ; LR:  0.004777998  ; EPSILON:  0.17897780961420182
# Collection
# Tapework
# epoch:  112  ; KL:  0.011341604  ; LR:  0.004775998  ; EPSILON:  0.1787988318045876
# Collection
# Tapework
# epoch:  113  ; KL:  0.006615419  ; LR:  0.004773998  ; EPSILON:  0.17862003297278303
# Collection
# Tapework
# epoch:  114  ; KL:  0.022299338  ; LR:  0.004771998  ; EPSILON:  0.17844141293981025
# Collection
# Tapework
# epoch:  115  ; KL:  0.019654755  ; LR:  0.004769998  ; EPSILON:  0.17826297152687043
# Collection
# Tapework
# epoch:  116  ; KL:  0.0033989884  ; LR:  0.004767998  ; EPSILON:  0.17808470855534356
# Collection
# Tapework
# epoch:  117  ; KL:  0.012897087  ; LR:  0.004765998  ; EPSILON:  0.1779066238467882
# Collection
# Tapework
# epoch:  118  ; KL:  0.017708434  ; LR:  0.004763998  ; EPSILON:  0.17772871722294142
# Collection
# Tapework
# epoch:  119  ; KL:  0.013720182  ; LR:  0.004761998  ; EPSILON:  0.1775509885057185
# Collection
# Tapework
# epoch:  120  ; KL:  0.013293445  ; LR:  0.004759998  ; EPSILON:  0.17737343751721277
# Collection
# Tapework
# epoch:  121  ; KL:  0.0326882  ; LR:  0.004757998  ; EPSILON:  0.17719606407969554
# Collection
# Tapework
# epoch:  122  ; KL:  0.013680719  ; LR:  0.004755998  ; EPSILON:  0.17701886801561584
# Collection
# Tapework
# epoch:  123  ; KL:  0.0014696474  ; LR:  0.004753998  ; EPSILON:  0.17684184914760023
# Collection
# Tapework
# epoch:  124  ; KL:  0.012058094  ; LR:  0.004751998  ; EPSILON:  0.17666500729845264
# Collection
# Tapework
# epoch:  125  ; KL:  0.007693535  ; LR:  0.004749998  ; EPSILON:  0.17648834229115418
# Collection
# Tapework
# epoch:  126  ; KL:  0.01171048  ; LR:  0.004747998  ; EPSILON:  0.17631185394886303
# Collection
# Tapework
# epoch:  127  ; KL:  0.003051461  ; LR:  0.004745998  ; EPSILON:  0.17613554209491417
# Collection
# Tapework
# epoch:  128  ; KL:  0.014149939  ; LR:  0.004743998  ; EPSILON:  0.17595940655281925
# Collection
# Tapework
# epoch:  129  ; KL:  0.010770646  ; LR:  0.004741998  ; EPSILON:  0.17578344714626642
# Collection
# Tapework
# epoch:  130  ; KL:  0.0066308435  ; LR:  0.004739998  ; EPSILON:  0.17560766369912015
# Collection
# Tapework
# epoch:  131  ; KL:  0.009511663  ; LR:  0.004737998  ; EPSILON:  0.17543205603542103
# Collection
# Tapework
# epoch:  132  ; KL:  0.0012625178  ; LR:  0.004735998  ; EPSILON:  0.1752566239793856
# Collection
# Tapework
# epoch:  133  ; KL:  0.008284954  ; LR:  0.004733998  ; EPSILON:  0.17508136735540622
# Collection
# Tapework
# epoch:  134  ; KL:  0.0026272384  ; LR:  0.004731998  ; EPSILON:  0.1749062859880508
# Collection
# Tapework
# epoch:  135  ; KL:  0.0034435121  ; LR:  0.004729998  ; EPSILON:  0.17473137970206276
# Collection
# Tapework
# epoch:  136  ; KL:  0.0042058444  ; LR:  0.004727998  ; EPSILON:  0.1745566483223607
# Collection
# Tapework
# epoch:  137  ; KL:  0.011821683  ; LR:  0.004725998  ; EPSILON:  0.17438209167403834
# Collection
# Tapework
# epoch:  138  ; KL:  0.017560413  ; LR:  0.004723998  ; EPSILON:  0.1742077095823643
# Collection
# Tapework
# epoch:  139  ; KL:  0.010262903  ; LR:  0.004721998  ; EPSILON:  0.17403350187278194
# Collection
# Tapework
# epoch:  140  ; KL:  0.0028395376  ; LR:  0.0047199978  ; EPSILON:  0.17385946837090915
# Collection
# Tapework
# epoch:  141  ; KL:  0.005713756  ; LR:  0.0047179977  ; EPSILON:  0.17368560890253826
# Collection
# Tapework
# epoch:  142  ; KL:  0.016686372  ; LR:  0.0047159977  ; EPSILON:  0.1735119232936357
# Collection
# Tapework
# epoch:  143  ; KL:  0.0071632885  ; LR:  0.0047139977  ; EPSILON:  0.1733384113703421
# Collection
# Tapework
# epoch:  144  ; KL:  0.00395185  ; LR:  0.0047119977  ; EPSILON:  0.17316507295897174
# Collection
# Tapework
# epoch:  145  ; KL:  0.0031617503  ; LR:  0.0047099977  ; EPSILON:  0.17299190788601276
# Collection
# Tapework
# epoch:  146  ; KL:  0.016209705  ; LR:  0.0047079977  ; EPSILON:  0.17281891597812676
# Collection
# Tapework
# epoch:  147  ; KL:  0.0107607525  ; LR:  0.0047059976  ; EPSILON:  0.17264609706214865
# Collection
# Tapework
# epoch:  148  ; KL:  0.0036367578  ; LR:  0.0047039976  ; EPSILON:  0.17247345096508648
# Collection
# Tapework
# epoch:  149  ; KL:  0.00905831  ; LR:  0.0047019976  ; EPSILON:  0.1723009775141214
# Collection
# Tapework
# epoch:  150  ; KL:  0.008776256  ; LR:  0.0046999976  ; EPSILON:  0.1721286765366073
# Collection
# Tapework
# epoch:  151  ; KL:  0.009329192  ; LR:  0.0046979976  ; EPSILON:  0.1719565478600707
# Collection
# Tapework
# epoch:  152  ; KL:  0.041975264  ; LR:  0.0046959976  ; EPSILON:  0.17178459131221063
# Collection
# Tapework
# epoch:  153  ; KL:  0.010409645  ; LR:  0.0046939976  ; EPSILON:  0.17161280672089843
# Collection
# Tapework
# epoch:  154  ; KL:  0.0031180333  ; LR:  0.0046919975  ; EPSILON:  0.17144119391417753
# Collection
# Tapework
# epoch:  155  ; KL:  0.0067526307  ; LR:  0.0046899975  ; EPSILON:  0.17126975272026335
# Collection
# Tapework
# epoch:  156  ; KL:  0.012721553  ; LR:  0.0046879975  ; EPSILON:  0.17109848296754307
# Collection
# Tapework
# epoch:  157  ; KL:  0.01680025  ; LR:  0.0046859975  ; EPSILON:  0.17092738448457553
# Collection
# Tapework
# epoch:  158  ; KL:  0.0017071753  ; LR:  0.0046839975  ; EPSILON:  0.17075645710009096
# Collection
# Tapework
# epoch:  159  ; KL:  0.019955149  ; LR:  0.0046819975  ; EPSILON:  0.17058570064299086
# Collection
# Tapework
# epoch:  160  ; KL:  0.017239714  ; LR:  0.0046799975  ; EPSILON:  0.17041511494234787
# Collection
# Tapework
# epoch:  161  ; KL:  0.023156874  ; LR:  0.0046779974  ; EPSILON:  0.17024469982740553
# Collection
# Tapework
# epoch:  162  ; KL:  0.0089269625  ; LR:  0.0046759974  ; EPSILON:  0.17007445512757813
# Collection
# Tapework
# epoch:  163  ; KL:  0.019120688  ; LR:  0.0046739974  ; EPSILON:  0.16990438067245056
# Collection
# Tapework
# epoch:  164  ; KL:  0.0021449737  ; LR:  0.0046719974  ; EPSILON:  0.1697344762917781
# Collection
# Tapework
# epoch:  165  ; KL:  0.014879331  ; LR:  0.0046699974  ; EPSILON:  0.1695647418154863
# Collection
# Tapework
# epoch:  166  ; KL:  0.029919706  ; LR:  0.0046679974  ; EPSILON:  0.16939517707367083
# Collection
# Tapework
# epoch:  167  ; KL:  0.008900391  ; LR:  0.0046659973  ; EPSILON:  0.16922578189659715
# Collection
# Tapework
# epoch:  168  ; KL:  0.017888429  ; LR:  0.0046639973  ; EPSILON:  0.16905655611470055
# Collection
# Tapework
# epoch:  169  ; KL:  0.02556042  ; LR:  0.0046619973  ; EPSILON:  0.16888749955858584
# Collection
# Tapework
# epoch:  170  ; KL:  0.0029066352  ; LR:  0.0046599973  ; EPSILON:  0.16871861205902725
# Collection
# Tapework
# epoch:  171  ; KL:  0.036590714  ; LR:  0.0046579973  ; EPSILON:  0.16854989344696822
# Collection
# Tapework
# epoch:  172  ; KL:  0.010211718  ; LR:  0.0046559973  ; EPSILON:  0.16838134355352125
# Collection
# Tapework
# epoch:  173  ; KL:  0.022017153  ; LR:  0.0046539973  ; EPSILON:  0.16821296220996773
# Collection
# Tapework
# epoch:  174  ; KL:  0.021214213  ; LR:  0.0046519972  ; EPSILON:  0.16804474924775775
# Collection
# Tapework
# epoch:  175  ; KL:  0.01826307  ; LR:  0.004649997  ; EPSILON:  0.16787670449851
# Collection
# Tapework
# epoch:  176  ; KL:  0.011912532  ; LR:  0.004647997  ; EPSILON:  0.1677088277940115
# Collection
# Tapework
# epoch:  177  ; KL:  0.029353881  ; LR:  0.004645997  ; EPSILON:  0.16754111896621748
# Collection
# Tapework
# epoch:  178  ; KL:  0.0029373285  ; LR:  0.004643997  ; EPSILON:  0.16737357784725126
# Collection
# Tapework
# epoch:  179  ; KL:  0.0012473484  ; LR:  0.004641997  ; EPSILON:  0.16720620426940402
# Collection
# Tapework
# epoch:  180  ; KL:  0.006794949  ; LR:  0.004639997  ; EPSILON:  0.16703899806513461
# Collection
# Tapework
# epoch:  181  ; KL:  0.022560732  ; LR:  0.004637997  ; EPSILON:  0.16687195906706948
# Collection
# Tapework
# epoch:  182  ; KL:  0.040722705  ; LR:  0.004635997  ; EPSILON:  0.16670508710800241
# Collection
# Tapework
# epoch:  183  ; KL:  0.015281746  ; LR:  0.004633997  ; EPSILON:  0.1665383820208944
# Collection
# Tapework
# epoch:  184  ; KL:  0.049609553  ; LR:  0.004631997  ; EPSILON:  0.16637184363887353
# Collection
# Tapework
# epoch:  185  ; KL:  0.010734456  ; LR:  0.004629997  ; EPSILON:  0.16620547179523465
# Collection
# Tapework
# epoch:  186  ; KL:  0.00741302  ; LR:  0.004627997  ; EPSILON:  0.1660392663234394
# Collection
# Tapework
# epoch:  187  ; KL:  0.0014179801  ; LR:  0.004625997  ; EPSILON:  0.16587322705711596
# Collection
# Tapework
# epoch:  188  ; KL:  0.014834634  ; LR:  0.004623997  ; EPSILON:  0.16570735383005886
# Collection
# Tapework
# epoch:  189  ; KL:  0.014555772  ; LR:  0.004621997  ; EPSILON:  0.1655416464762288
# Collection
# Tapework
# epoch:  190  ; KL:  0.033397812  ; LR:  0.004619997  ; EPSILON:  0.16537610482975257
# Collection
# Tapework
# epoch:  191  ; KL:  0.029006775  ; LR:  0.004617997  ; EPSILON:  0.16521072872492282
# Collection
# Tapework
# epoch:  192  ; KL:  0.015248655  ; LR:  0.004615997  ; EPSILON:  0.1650455179961979
# Collection
# Tapework
# epoch:  193  ; KL:  0.0023922934  ; LR:  0.004613997  ; EPSILON:  0.1648804724782017
# Collection
# Tapework
# epoch:  194  ; KL:  0.03072676  ; LR:  0.004611997  ; EPSILON:  0.1647155920057235
# Collection
# Tapework
# epoch:  195  ; KL:  0.019874012  ; LR:  0.004609997  ; EPSILON:  0.16455087641371777
# Collection
# Tapework
# epoch:  196  ; KL:  0.037277598  ; LR:  0.004607997  ; EPSILON:  0.16438632553730406
# Collection
# Tapework
# epoch:  197  ; KL:  0.028303925  ; LR:  0.004605997  ; EPSILON:  0.16422193921176675
# Collection
# Tapework
# epoch:  198  ; KL:  0.020776989  ; LR:  0.004603997  ; EPSILON:  0.164057717272555
# Collection
# Tapework
# epoch:  199  ; KL:  0.030693887  ; LR:  0.004601997  ; EPSILON:  0.16389365955528246
# Collection
# Tapework
# epoch:  200  ; KL:  0.022214249  ; LR:  0.004599997  ; EPSILON:  0.1637297658957272
# Collection
# Tapework
# epoch:  201  ; KL:  0.010292649  ; LR:  0.004597997  ; EPSILON:  0.16356603612983145
# Collection
# Tapework
# epoch:  202  ; KL:  0.014251176  ; LR:  0.004595997  ; EPSILON:  0.16340247009370162
# Collection
# Tapework
# epoch:  203  ; KL:  0.0015917335  ; LR:  0.004593997  ; EPSILON:  0.16323906762360793
# Collection
# Tapework
# epoch:  204  ; KL:  0.01283021  ; LR:  0.004591997  ; EPSILON:  0.16307582855598432
# Collection
# Tapework
# epoch:  205  ; KL:  0.007792574  ; LR:  0.0045899968  ; EPSILON:  0.16291275272742833
# Collection
# Tapework
# epoch:  206  ; KL:  0.005766629  ; LR:  0.0045879968  ; EPSILON:  0.1627498399747009
# Collection
# Tapework
# epoch:  207  ; KL:  0.008028526  ; LR:  0.0045859967  ; EPSILON:  0.16258709013472622
# Collection
# Tapework
# epoch:  208  ; KL:  0.04008164  ; LR:  0.0045839967  ; EPSILON:  0.1624245030445915
# Collection
# Tapework
# epoch:  209  ; KL:  0.040755242  ; LR:  0.0045819967  ; EPSILON:  0.1622620785415469
# Collection
# Tapework
# epoch:  210  ; KL:  0.016433945  ; LR:  0.0045799967  ; EPSILON:  0.16209981646300534
# Collection
# Tapework
# epoch:  211  ; KL:  0.050770584  ; LR:  0.0045779967  ; EPSILON:  0.16193771664654233
# Collection
# Tapework
# epoch:  212  ; KL:  0.012049974  ; LR:  0.0045759967  ; EPSILON:  0.16177577892989578
# Collection
# Tapework
# epoch:  213  ; KL:  0.01035339  ; LR:  0.0045739966  ; EPSILON:  0.16161400315096588
# Collection
# Tapework
# epoch:  214  ; KL:  0.010351463  ; LR:  0.0045719966  ; EPSILON:  0.16145238914781493
# Collection
# Tapework
# epoch:  215  ; KL:  0.021890441  ; LR:  0.0045699966  ; EPSILON:  0.16129093675866712
# Collection
# Tapework
# epoch:  216  ; KL:  0.008007203  ; LR:  0.0045679966  ; EPSILON:  0.16112964582190845
# Collection
# Tapework
# epoch:  217  ; KL:  0.015237622  ; LR:  0.0045659966  ; EPSILON:  0.16096851617608654
# Collection
# Tapework
# epoch:  218  ; KL:  0.014854614  ; LR:  0.0045639966  ; EPSILON:  0.16080754765991045
# Collection
# Tapework
# epoch:  219  ; KL:  0.017585503  ; LR:  0.0045619966  ; EPSILON:  0.16064674011225055
# Collection
# Tapework
# epoch:  220  ; KL:  0.00092084386  ; LR:  0.0045599965  ; EPSILON:  0.1604860933721383
# Collection
# Tapework
# epoch:  221  ; KL:  0.005176026  ; LR:  0.0045579965  ; EPSILON:  0.16032560727876616
# Collection
# Tapework
# epoch:  222  ; KL:  0.0029153684  ; LR:  0.0045559965  ; EPSILON:  0.1601652816714874
# Collection
# Tapework
# epoch:  223  ; KL:  0.018375212  ; LR:  0.0045539965  ; EPSILON:  0.1600051163898159
# Collection
# Tapework
# epoch:  224  ; KL:  0.025041796  ; LR:  0.0045519965  ; EPSILON:  0.1598451112734261
# Collection
# Tapework
# epoch:  225  ; KL:  0.021246558  ; LR:  0.0045499965  ; EPSILON:  0.15968526616215267
# Collection
# Tapework
# epoch:  226  ; KL:  0.010792868  ; LR:  0.0045479964  ; EPSILON:  0.15952558089599053
# Collection
# Tapework
# epoch:  227  ; KL:  0.02477424  ; LR:  0.0045459964  ; EPSILON:  0.15936605531509454
# Collection
# Tapework
# epoch:  228  ; KL:  0.011666398  ; LR:  0.0045439964  ; EPSILON:  0.15920668925977943
# Collection
# Tapework
# epoch:  229  ; KL:  0.016691426  ; LR:  0.0045419964  ; EPSILON:  0.15904748257051965
# Collection
# Tapework
# epoch:  230  ; KL:  0.01010469  ; LR:  0.0045399964  ; EPSILON:  0.15888843508794914
# Collection
# Tapework
# epoch:  231  ; KL:  0.014619187  ; LR:  0.0045379964  ; EPSILON:  0.15872954665286118
# Collection
# Tapework
# epoch:  232  ; KL:  0.027507681  ; LR:  0.0045359964  ; EPSILON:  0.15857081710620832
# Collection
# Tapework
# epoch:  233  ; KL:  0.004240556  ; LR:  0.0045339963  ; EPSILON:  0.1584122462891021
# Collection
# Tapework
# epoch:  234  ; KL:  0.009977794  ; LR:  0.0045319963  ; EPSILON:  0.158253834042813
# Collection
# Tapework
# epoch:  235  ; KL:  0.0055015003  ; LR:  0.0045299963  ; EPSILON:  0.1580955802087702
# Collection
# Tapework
# epoch:  236  ; KL:  0.026816726  ; LR:  0.0045279963  ; EPSILON:  0.15793748462856144
# Collection
# Tapework
# epoch:  237  ; KL:  0.028468639  ; LR:  0.0045259963  ; EPSILON:  0.15777954714393289
# Collection
# Tapework
# epoch:  238  ; KL:  0.012416009  ; LR:  0.0045239963  ; EPSILON:  0.15762176759678895
# Collection
# Tapework
# epoch:  239  ; KL:  0.0021255938  ; LR:  0.0045219962  ; EPSILON:  0.15746414582919216
# Collection
# Tapework
# epoch:  240  ; KL:  0.031249816  ; LR:  0.0045199962  ; EPSILON:  0.15730668168336295
# Collection
# Tapework
# epoch:  241  ; KL:  0.022365883  ; LR:  0.004517996  ; EPSILON:  0.15714937500167958
# Collection
# Tapework
# epoch:  242  ; KL:  0.03397281  ; LR:  0.004515996  ; EPSILON:  0.1569922256266779
# Collection
# Tapework
# epoch:  243  ; KL:  0.00950699  ; LR:  0.004513996  ; EPSILON:  0.1568352334010512
# Collection
# Tapework
# epoch:  244  ; KL:  0.026142297  ; LR:  0.004511996  ; EPSILON:  0.15667839816765017
# Collection
# Tapework
# epoch:  245  ; KL:  0.030774046  ; LR:  0.004509996  ; EPSILON:  0.1565217197694825
# Collection
# Tapework
# epoch:  246  ; KL:  0.020551061  ; LR:  0.004507996  ; EPSILON:  0.15636519804971302
# Collection
# Tapework
# epoch:  247  ; KL:  0.01523432  ; LR:  0.004505996  ; EPSILON:  0.15620883285166332
# Collection
# Tapework
# epoch:  248  ; KL:  0.00721062  ; LR:  0.004503996  ; EPSILON:  0.15605262401881165
# Collection
# Tapework
# epoch:  249  ; KL:  0.032733083  ; LR:  0.004501996  ; EPSILON:  0.15589657139479285
# Collection
# Tapework
# epoch:  250  ; KL:  0.028671823  ; LR:  0.004499996  ; EPSILON:  0.15574067482339807
# Collection
# Tapework
# epoch:  251  ; KL:  0.003970697  ; LR:  0.004497996  ; EPSILON:  0.15558493414857466
# Collection
# Tapework
# epoch:  252  ; KL:  0.045206636  ; LR:  0.004495996  ; EPSILON:  0.15542934921442608
# Collection
# Tapework
# epoch:  253  ; KL:  0.0032634896  ; LR:  0.004493996  ; EPSILON:  0.15527391986521166
# Collection
# Tapework
# epoch:  254  ; KL:  0.020217584  ; LR:  0.004491996  ; EPSILON:  0.15511864594534644
# Collection
# Tapework
# epoch:  255  ; KL:  0.010118424  ; LR:  0.004489996  ; EPSILON:  0.1549635272994011
# Collection
# Tapework
# epoch:  256  ; KL:  0.0030482796  ; LR:  0.004487996  ; EPSILON:  0.1548085637721017
# Collection
# Tapework
# epoch:  257  ; KL:  0.017468132  ; LR:  0.004485996  ; EPSILON:  0.1546537552083296
# Collection
# Tapework
# epoch:  258  ; KL:  0.017757863  ; LR:  0.004483996  ; EPSILON:  0.1544991014531213
# Collection
# Tapework
# epoch:  259  ; KL:  0.016917855  ; LR:  0.004481996  ; EPSILON:  0.15434460235166816
# Collection
# Tapework
# epoch:  260  ; KL:  0.041586194  ; LR:  0.004479996  ; EPSILON:  0.1541902577493165
# Collection
# Tapework
# epoch:  261  ; KL:  0.008506184  ; LR:  0.004477996  ; EPSILON:  0.15403606749156717
# Collection
# Tapework
# epoch:  262  ; KL:  0.045082014  ; LR:  0.004475996  ; EPSILON:  0.1538820314240756
# Collection
# Tapework
# epoch:  263  ; KL:  0.018450031  ; LR:  0.004473996  ; EPSILON:  0.15372814939265153
# Collection
# Tapework
# epoch:  264  ; KL:  0.009212226  ; LR:  0.004471996  ; EPSILON:  0.15357442124325887
# Collection
# Tapework
# epoch:  265  ; KL:  0.008226466  ; LR:  0.004469996  ; EPSILON:  0.15342084682201562
# Collection
# Tapework
# epoch:  266  ; KL:  0.016482417  ; LR:  0.004467996  ; EPSILON:  0.1532674259751936
# Collection
# Tapework
# epoch:  267  ; KL:  0.022115722  ; LR:  0.004465996  ; EPSILON:  0.15311415854921842
# Collection
# Tapework
# epoch:  268  ; KL:  0.029221807  ; LR:  0.004463996  ; EPSILON:  0.1529610443906692
# Collection
# Tapework
# epoch:  269  ; KL:  0.012858689  ; LR:  0.004461996  ; EPSILON:  0.15280808334627854
# Collection
# Tapework
# epoch:  270  ; KL:  0.021692831  ; LR:  0.004459996  ; EPSILON:  0.15265527526293227
# Collection
# Tapework
# epoch:  271  ; KL:  0.012951443  ; LR:  0.0044579958  ; EPSILON:  0.15250261998766934
# Collection
# Tapework
# epoch:  272  ; KL:  0.025767034  ; LR:  0.0044559957  ; EPSILON:  0.15235011736768167
# Collection
# Tapework
# epoch:  273  ; KL:  0.050071348  ; LR:  0.0044539957  ; EPSILON:  0.15219776725031398
# Collection
# Tapework
# epoch:  274  ; KL:  0.05158636  ; LR:  0.0044519957  ; EPSILON:  0.15204556948306366
# Collection
# Tapework
# epoch:  275  ; KL:  0.005032206  ; LR:  0.0044499957  ; EPSILON:  0.1518935239135806
# Collection
# Tapework
# epoch:  276  ; KL:  0.012564679  ; LR:  0.0044479957  ; EPSILON:  0.151741630389667
# Collection
# Tapework
# epoch:  277  ; KL:  0.008954774  ; LR:  0.0044459957  ; EPSILON:  0.15158988875927734
# Collection
# Tapework
# epoch:  278  ; KL:  0.007835669  ; LR:  0.0044439957  ; EPSILON:  0.15143829887051807
# Collection
# Tapework
# epoch:  279  ; KL:  0.024949243  ; LR:  0.0044419956  ; EPSILON:  0.15128686057164756
# Collection
# Tapework
# epoch:  280  ; KL:  0.0053220293  ; LR:  0.0044399956  ; EPSILON:  0.15113557371107592
# Collection
# Tapework
# epoch:  281  ; KL:  0.0060248203  ; LR:  0.0044379956  ; EPSILON:  0.15098443813736484
# Collection
# Tapework
# epoch:  282  ; KL:  0.019695744  ; LR:  0.0044359956  ; EPSILON:  0.1508334536992275
# Collection
# Tapework
# epoch:  283  ; KL:  0.013986986  ; LR:  0.0044339956  ; EPSILON:  0.15068262024552825
# Collection
# Tapework
# epoch:  284  ; KL:  0.009404961  ; LR:  0.0044319956  ; EPSILON:  0.15053193762528272
# Collection
# Tapework
# epoch:  285  ; KL:  0.019568123  ; LR:  0.0044299955  ; EPSILON:  0.15038140568765743
# Collection
# Tapework
# epoch:  286  ; KL:  0.0092175  ; LR:  0.0044279955  ; EPSILON:  0.15023102428196977
# Collection
# Tapework
# epoch:  287  ; KL:  0.044949368  ; LR:  0.0044259955  ; EPSILON:  0.1500807932576878
# Collection
# Tapework
# epoch:  288  ; KL:  0.020440135  ; LR:  0.0044239955  ; EPSILON:  0.14993071246443013
# Collection
# Tapework
# epoch:  289  ; KL:  0.014567259  ; LR:  0.0044219955  ; EPSILON:  0.14978078175196569
# Collection
# Tapework
# epoch:  290  ; KL:  0.028647337  ; LR:  0.0044199955  ; EPSILON:  0.14963100097021373
# Collection
# Tapework
# epoch:  291  ; KL:  0.016482148  ; LR:  0.0044179955  ; EPSILON:  0.14948136996924352
# Collection
# Tapework
# epoch:  292  ; KL:  0.015950821  ; LR:  0.0044159954  ; EPSILON:  0.14933188859927427
# Collection
# Tapework
# epoch:  293  ; KL:  0.024018468  ; LR:  0.0044139954  ; EPSILON:  0.14918255671067499
# Collection
# Tapework
# epoch:  294  ; KL:  0.0053756908  ; LR:  0.0044119954  ; EPSILON:  0.1490333741539643
# Collection
# Tapework
# epoch:  295  ; KL:  0.027296081  ; LR:  0.0044099954  ; EPSILON:  0.14888434077981036
# Collection
# Tapework
# epoch:  296  ; KL:  0.016235488  ; LR:  0.0044079954  ; EPSILON:  0.14873545643903055
# Collection
# Tapework
# epoch:  297  ; KL:  0.0056154463  ; LR:  0.0044059954  ; EPSILON:  0.1485867209825915
# Collection
# Tapework
# epoch:  298  ; KL:  0.02303059  ; LR:  0.0044039954  ; EPSILON:  0.14843813426160893
# Collection
# Tapework
# epoch:  299  ; KL:  0.007850229  ; LR:  0.0044019953  ; EPSILON:  0.14828969612734733
# Collection
# Tapework
# epoch:  300  ; KL:  0.020887557  ; LR:  0.0043999953  ; EPSILON:  0.14814140643121998
# Collection
# Tapework
# epoch:  301  ; KL:  0.017037092  ; LR:  0.0043979953  ; EPSILON:  0.14799326502478877
# Collection
# Tapework
# epoch:  302  ; KL:  0.005107759  ; LR:  0.0043959953  ; EPSILON:  0.14784527175976397
# Collection
# Tapework
# epoch:  303  ; KL:  0.032969408  ; LR:  0.0043939953  ; EPSILON:  0.1476974264880042
# Collection
# Tapework
# epoch:  304  ; KL:  0.008882242  ; LR:  0.0043919953  ; EPSILON:  0.1475497290615162
# Collection
# Tapework
# epoch:  305  ; KL:  0.007968379  ; LR:  0.0043899952  ; EPSILON:  0.14740217933245467
# Collection
# Tapework
# epoch:  306  ; KL:  0.009186376  ; LR:  0.004387995  ; EPSILON:  0.1472547771531222
# Collection
# Tapework
# epoch:  307  ; KL:  0.043856293  ; LR:  0.004385995  ; EPSILON:  0.14710752237596908
# Collection
# Tapework
# epoch:  308  ; KL:  0.014686788  ; LR:  0.004383995  ; EPSILON:  0.14696041485359312
# Collection
# Tapework
# epoch:  309  ; KL:  0.023565477  ; LR:  0.004381995  ; EPSILON:  0.14681345443873953
# Collection
# Tapework
# epoch:  310  ; KL:  0.004741992  ; LR:  0.004379995  ; EPSILON:  0.1466666409843008
# Collection
# Tapework
# epoch:  311  ; KL:  0.01790956  ; LR:  0.004377995  ; EPSILON:  0.14651997434331648
# Collection
# Tapework
# epoch:  312  ; KL:  0.040244244  ; LR:  0.004375995  ; EPSILON:  0.14637345436897317
# Collection
# Tapework
# epoch:  313  ; KL:  0.01130792  ; LR:  0.004373995  ; EPSILON:  0.1462270809146042
# Collection
# Tapework
# epoch:  314  ; KL:  0.034790065  ; LR:  0.004371995  ; EPSILON:  0.1460808538336896
# Collection
# Tapework
# epoch:  315  ; KL:  0.0067027113  ; LR:  0.004369995  ; EPSILON:  0.1459347729798559
# Collection
# Tapework
# epoch:  316  ; KL:  0.011663819  ; LR:  0.004367995  ; EPSILON:  0.14578883820687605
# Collection
# Tapework
# epoch:  317  ; KL:  0.012121536  ; LR:  0.004365995  ; EPSILON:  0.14564304936866918
# Collection
# Tapework
# epoch:  318  ; KL:  0.011706209  ; LR:  0.004363995  ; EPSILON:  0.1454974063193005
# Collection
# Tapework
# epoch:  319  ; KL:  0.017704222  ; LR:  0.004361995  ; EPSILON:  0.1453519089129812
# Collection
# Tapework
# epoch:  320  ; KL:  0.014571817  ; LR:  0.004359995  ; EPSILON:  0.1452065570040682
# Collection
# Tapework
# epoch:  321  ; KL:  0.011789969  ; LR:  0.004357995  ; EPSILON:  0.14506135044706414
# Collection
# Tapework
# epoch:  322  ; KL:  0.05418684  ; LR:  0.004355995  ; EPSILON:  0.14491628909661708
# Collection
# Tapework
# epoch:  323  ; KL:  0.019284755  ; LR:  0.004353995  ; EPSILON:  0.14477137280752045
# Collection
# Tapework
# epoch:  324  ; KL:  0.020599  ; LR:  0.004351995  ; EPSILON:  0.14462660143471293
# Collection
# Tapework
# epoch:  325  ; KL:  0.0060547167  ; LR:  0.004349995  ; EPSILON:  0.1444819748332782
# Collection
# Tapework
# epoch:  326  ; KL:  0.021598123  ; LR:  0.004347995  ; EPSILON:  0.14433749285844494
# Collection
# Tapework
# epoch:  327  ; KL:  0.043778934  ; LR:  0.004345995  ; EPSILON:  0.1441931553655865
# Collection
# Tapework
# epoch:  328  ; KL:  0.0029852388  ; LR:  0.004343995  ; EPSILON:  0.1440489622102209
# Collection
# Tapework
# epoch:  329  ; KL:  0.01836937  ; LR:  0.004341995  ; EPSILON:  0.1439049132480107
# Collection
# Tapework
# epoch:  330  ; KL:  0.018297723  ; LR:  0.004339995  ; EPSILON:  0.14376100833476269
# Collection
# Tapework
# epoch:  331  ; KL:  0.017865868  ; LR:  0.004337995  ; EPSILON:  0.14361724732642792
# Collection
# Tapework
# epoch:  332  ; KL:  0.01891441  ; LR:  0.004335995  ; EPSILON:  0.1434736300791015
# Collection
# Tapework
# epoch:  333  ; KL:  0.00094615587  ; LR:  0.004333995  ; EPSILON:  0.1433301564490224
# Collection
# Tapework
# epoch:  334  ; KL:  0.0040455163  ; LR:  0.004331995  ; EPSILON:  0.14318682629257337
# Collection
# Tapework
# epoch:  335  ; KL:  0.005310556  ; LR:  0.004329995  ; EPSILON:  0.1430436394662808
# Collection
# Tapework
# epoch:  336  ; KL:  0.021043587  ; LR:  0.004327995  ; EPSILON:  0.14290059582681452
# Collection
# Tapework
# epoch:  337  ; KL:  0.0053140665  ; LR:  0.0043259948  ; EPSILON:  0.14275769523098772
# Collection
# Tapework
# epoch:  338  ; KL:  0.018706106  ; LR:  0.0043239947  ; EPSILON:  0.14261493753575674
# Collection
# Tapework
# epoch:  339  ; KL:  0.008649796  ; LR:  0.0043219947  ; EPSILON:  0.14247232259822099
# Collection
# Tapework
# epoch:  340  ; KL:  0.012157842  ; LR:  0.0043199947  ; EPSILON:  0.14232985027562275
# Collection
# Tapework
# epoch:  341  ; KL:  0.003441483  ; LR:  0.0043179947  ; EPSILON:  0.14218752042534713
# Collection
# Tapework
# epoch:  342  ; KL:  0.0050667184  ; LR:  0.0043159947  ; EPSILON:  0.14204533290492177
# Collection
# Tapework
# epoch:  343  ; KL:  0.004413269  ; LR:  0.0043139947  ; EPSILON:  0.14190328757201684
# Collection
# Tapework
# epoch:  344  ; KL:  0.032266144  ; LR:  0.0043119946  ; EPSILON:  0.14176138428444482
# Collection
# Tapework
# epoch:  345  ; KL:  0.008274905  ; LR:  0.0043099946  ; EPSILON:  0.14161962290016036
# Collection
# Tapework
# epoch:  346  ; KL:  0.016485374  ; LR:  0.0043079946  ; EPSILON:  0.1414780032772602
# Collection
# Tapework
# epoch:  347  ; KL:  0.024150377  ; LR:  0.0043059946  ; EPSILON:  0.14133652527398294
# Collection
# Tapework
# epoch:  348  ; KL:  0.007351949  ; LR:  0.0043039946  ; EPSILON:  0.14119518874870896
# Collection
# Tapework
# epoch:  349  ; KL:  0.011095475  ; LR:  0.0043019946  ; EPSILON:  0.14105399355996023
# Collection
# Tapework
# epoch:  350  ; KL:  0.012515917  ; LR:  0.0042999946  ; EPSILON:  0.14091293956640027
# Collection
# Tapework
# epoch:  351  ; KL:  0.014393248  ; LR:  0.0042979945  ; EPSILON:  0.14077202662683388
# Collection
# Tapework
# epoch:  352  ; KL:  0.0022174278  ; LR:  0.0042959945  ; EPSILON:  0.14063125460020706
# Collection
# Tapework
# epoch:  353  ; KL:  0.012256943  ; LR:  0.0042939945  ; EPSILON:  0.14049062334560686
# Collection
# Tapework
# epoch:  354  ; KL:  0.006982001  ; LR:  0.0042919945  ; EPSILON:  0.14035013272226124
# Collection
# Tapework
# epoch:  355  ; KL:  0.019755708  ; LR:  0.0042899945  ; EPSILON:  0.14020978258953898
# Collection
# Tapework
# epoch:  356  ; KL:  0.018130774  ; LR:  0.0042879945  ; EPSILON:  0.14006957280694943
# Collection
# Tapework
# epoch:  357  ; KL:  0.008607555  ; LR:  0.0042859945  ; EPSILON:  0.13992950323414247
# Collection
# Tapework
# epoch:  358  ; KL:  0.044967536  ; LR:  0.0042839944  ; EPSILON:  0.13978957373090833
# Collection
# Tapework
# epoch:  359  ; KL:  0.0255479  ; LR:  0.0042819944  ; EPSILON:  0.13964978415717744
# Collection
# Tapework
# epoch:  360  ; KL:  0.0013252901  ; LR:  0.0042799944  ; EPSILON:  0.13951013437302026
# Collection
# Tapework
# epoch:  361  ; KL:  0.021624066  ; LR:  0.0042779944  ; EPSILON:  0.13937062423864724
# Collection
# Tapework
# epoch:  362  ; KL:  0.014484311  ; LR:  0.0042759944  ; EPSILON:  0.13923125361440858
# Collection
# Tapework
# epoch:  363  ; KL:  0.0485637  ; LR:  0.0042739944  ; EPSILON:  0.13909202236079418
# Collection
# Tapework
# epoch:  364  ; KL:  0.024336535  ; LR:  0.0042719943  ; EPSILON:  0.1389529303384334
# Collection
# Tapework
# epoch:  365  ; KL:  0.045161523  ; LR:  0.0042699943  ; EPSILON:  0.13881397740809495
# Collection
# Tapework
# epoch:  366  ; KL:  0.031524453  ; LR:  0.0042679943  ; EPSILON:  0.13867516343068687
# Collection
# Tapework
# epoch:  367  ; KL:  0.029904421  ; LR:  0.0042659943  ; EPSILON:  0.13853648826725617
# Collection
# Tapework
# epoch:  368  ; KL:  0.025711555  ; LR:  0.0042639943  ; EPSILON:  0.13839795177898892
# Collection
# Tapework
# epoch:  369  ; KL:  0.0010551196  ; LR:  0.0042619943  ; EPSILON:  0.13825955382720992
# Collection
# Tapework
# epoch:  370  ; KL:  0.011229714  ; LR:  0.0042599943  ; EPSILON:  0.1381212942733827
# Collection
# Tapework
# epoch:  371  ; KL:  0.018498762  ; LR:  0.0042579942  ; EPSILON:  0.13798317297910934
# Collection
# Tapework
# epoch:  372  ; KL:  0.016325064  ; LR:  0.004255994  ; EPSILON:  0.13784518980613022
# Collection
# Tapework
# epoch:  373  ; KL:  0.02572847  ; LR:  0.004253994  ; EPSILON:  0.13770734461632408
# Collection
# Tapework
# epoch:  374  ; KL:  0.009074681  ; LR:  0.004251994  ; EPSILON:  0.13756963727170776
# Collection
# Tapework
# epoch:  375  ; KL:  0.015407274  ; LR:  0.004249994  ; EPSILON:  0.13743206763443605
# Collection
# Tapework
# epoch:  376  ; KL:  0.003481588  ; LR:  0.004247994  ; EPSILON:  0.1372946355668016
# Collection
# Tapework
# epoch:  377  ; KL:  0.012213005  ; LR:  0.004245994  ; EPSILON:  0.1371573409312348
# Collection
# Tapework
# epoch:  378  ; KL:  0.0030342906  ; LR:  0.004243994  ; EPSILON:  0.13702018359030357
# Collection
# Tapework
# epoch:  379  ; KL:  0.039649278  ; LR:  0.004241994  ; EPSILON:  0.13688316340671328
# Collection
# Tapework
# epoch:  380  ; KL:  0.04074869  ; LR:  0.004239994  ; EPSILON:  0.13674628024330657
# Collection
# Tapework
# epoch:  381  ; KL:  0.015745196  ; LR:  0.004237994  ; EPSILON:  0.13660953396306327
# Collection
# Tapework
# epoch:  382  ; KL:  0.019241754  ; LR:  0.004235994  ; EPSILON:  0.13647292442910022
# Collection
# Tapework
# epoch:  383  ; KL:  0.017937452  ; LR:  0.004233994  ; EPSILON:  0.13633645150467114
# Collection
# Tapework
# epoch:  384  ; KL:  0.022811074  ; LR:  0.004231994  ; EPSILON:  0.13620011505316645
# Collection
# Tapework
# epoch:  385  ; KL:  0.012309843  ; LR:  0.004229994  ; EPSILON:  0.1360639149381133
# Collection
# Tapework
# epoch:  386  ; KL:  0.023800675  ; LR:  0.004227994  ; EPSILON:  0.13592785102317517
# Collection
# Tapework
# epoch:  387  ; KL:  0.009080737  ; LR:  0.004225994  ; EPSILON:  0.135791923172152
# Collection
# Tapework
# epoch:  388  ; KL:  0.017879352  ; LR:  0.004223994  ; EPSILON:  0.13565613124897985
# Collection
# Tapework
# epoch:  389  ; KL:  0.004295661  ; LR:  0.004221994  ; EPSILON:  0.13552047511773088
# Collection
# Tapework
# epoch:  390  ; KL:  0.030644998  ; LR:  0.004219994  ; EPSILON:  0.13538495464261316
# Collection
# Tapework
# epoch:  391  ; KL:  0.067187555  ; LR:  0.004217994  ; EPSILON:  0.13524956968797056
# Collection
# Tapework
# epoch:  392  ; KL:  0.013854297  ; LR:  0.004215994  ; EPSILON:  0.1351143201182826
# Collection
# Tapework
# epoch:  393  ; KL:  0.0046608634  ; LR:  0.004213994  ; EPSILON:  0.1349792057981643
# Collection
# Tapework
# epoch:  394  ; KL:  0.01942944  ; LR:  0.004211994  ; EPSILON:  0.13484422659236614
# Collection
# Tapework
# epoch:  395  ; KL:  0.036830284  ; LR:  0.004209994  ; EPSILON:  0.13470938236577376
# Collection
# Tapework
# epoch:  396  ; KL:  0.014919741  ; LR:  0.004207994  ; EPSILON:  0.134574672983408
# Collection
# Tapework
# epoch:  397  ; KL:  0.023297923  ; LR:  0.004205994  ; EPSILON:  0.13444009831042458
# Collection
# Tapework
# epoch:  398  ; KL:  0.003547861  ; LR:  0.004203994  ; EPSILON:  0.13430565821211415
# Collection
# Tapework
# epoch:  399  ; KL:  0.027454812  ; LR:  0.004201994  ; EPSILON:  0.13417135255390203
# Collection
# Tapework
# epoch:  400  ; KL:  0.0050810734  ; LR:  0.004199994  ; EPSILON:  0.13403718120134814
# Collection
# Tapework
# epoch:  401  ; KL:  0.1072225  ; LR:  0.004197994  ; EPSILON:  0.1339031440201468
# Collection
# Tapework
# epoch:  402  ; KL:  0.004574791  ; LR:  0.0041959938  ; EPSILON:  0.13376924087612665
# Collection
# Tapework
# epoch:  403  ; KL:  0.045106217  ; LR:  0.0041939938  ; EPSILON:  0.13363547163525052
# Collection
# Tapework
# epoch:  404  ; KL:  0.014973811  ; LR:  0.0041919937  ; EPSILON:  0.13350183616361527
# Collection
# Tapework
# epoch:  405  ; KL:  0.020688955  ; LR:  0.0041899937  ; EPSILON:  0.13336833432745165
# Collection
# Tapework
# epoch:  406  ; KL:  0.020068971  ; LR:  0.0041879937  ; EPSILON:  0.1332349659931242
# Collection
# Tapework
# epoch:  407  ; KL:  0.0016609341  ; LR:  0.0041859937  ; EPSILON:  0.13310173102713108
# Collection
# Tapework
# epoch:  408  ; KL:  0.010388739  ; LR:  0.0041839937  ; EPSILON:  0.13296862929610395
# Collection
# Tapework
# epoch:  409  ; KL:  0.011000241  ; LR:  0.0041819937  ; EPSILON:  0.13283566066680785
# Collection
# Tapework
# epoch:  410  ; KL:  0.014277244  ; LR:  0.0041799936  ; EPSILON:  0.13270282500614106
# Collection
# Tapework
# epoch:  411  ; KL:  0.0065873344  ; LR:  0.0041779936  ; EPSILON:  0.13257012218113493
# Collection
# Tapework
# epoch:  412  ; KL:  0.01221549  ; LR:  0.0041759936  ; EPSILON:  0.1324375520589538
# Collection
# Tapework
# epoch:  413  ; KL:  0.004156289  ; LR:  0.0041739936  ; EPSILON:  0.13230511450689483
# Collection
# Tapework
# epoch:  414  ; KL:  0.008646513  ; LR:  0.0041719936  ; EPSILON:  0.13217280939238793
# Collection
# Tapework
# epoch:  415  ; KL:  0.029356025  ; LR:  0.0041699936  ; EPSILON:  0.13204063658299553
# Collection
# Tapework
# epoch:  416  ; KL:  0.03184699  ; LR:  0.0041679936  ; EPSILON:  0.13190859594641252
# Collection
# Tapework
# epoch:  417  ; KL:  0.011051322  ; LR:  0.0041659935  ; EPSILON:  0.1317766873504661
# Collection
# Tapework
# epoch:  418  ; KL:  0.0012519639  ; LR:  0.0041639935  ; EPSILON:  0.13164491066311565
# Collection
# Tapework
# epoch:  419  ; KL:  0.0009173033  ; LR:  0.0041619935  ; EPSILON:  0.13151326575245254
# Collection
# Tapework
# epoch:  420  ; KL:  0.029280446  ; LR:  0.0041599935  ; EPSILON:  0.1313817524867001
# Collection
# Tapework
# epoch:  421  ; KL:  0.009955966  ; LR:  0.0041579935  ; EPSILON:  0.1312503707342134
# Collection
# Tapework
# epoch:  422  ; KL:  0.016894203  ; LR:  0.0041559935  ; EPSILON:  0.13111912036347917
# Collection
# Tapework
# epoch:  423  ; KL:  0.014433789  ; LR:  0.0041539934  ; EPSILON:  0.1309880012431157
# Collection
# Tapework
# epoch:  424  ; KL:  0.03668025  ; LR:  0.0041519934  ; EPSILON:  0.13085701324187257
# Collection
# Tapework
# epoch:  425  ; KL:  0.0032205004  ; LR:  0.0041499934  ; EPSILON:  0.1307261562286307
# Collection
# Tapework
# epoch:  426  ; KL:  0.0045181876  ; LR:  0.0041479934  ; EPSILON:  0.13059543007240207
# Collection
# Tapework
# epoch:  427  ; KL:  0.0023406553  ; LR:  0.0041459934  ; EPSILON:  0.13046483464232966
# Collection
# Tapework
# epoch:  428  ; KL:  0.03904913  ; LR:  0.0041439934  ; EPSILON:  0.13033436980768734
# Collection
# Tapework
# epoch:  429  ; KL:  0.014685145  ; LR:  0.0041419934  ; EPSILON:  0.13020403543787964
# Collection
# Tapework
# epoch:  430  ; KL:  0.0037341905  ; LR:  0.0041399933  ; EPSILON:  0.13007383140244178
# Collection
# Tapework
# epoch:  431  ; KL:  0.025564624  ; LR:  0.0041379933  ; EPSILON:  0.12994375757103932
# Collection
# Tapework
# epoch:  432  ; KL:  0.010980639  ; LR:  0.0041359933  ; EPSILON:  0.1298138138134683
# Collection
# Tapework
# epoch:  433  ; KL:  0.009110311  ; LR:  0.0041339933  ; EPSILON:  0.12968399999965483
# Collection
# Tapework
# epoch:  434  ; KL:  0.008625954  ; LR:  0.0041319933  ; EPSILON:  0.12955431599965517
# Collection
# Tapework
# epoch:  435  ; KL:  0.012828474  ; LR:  0.0041299933  ; EPSILON:  0.12942476168365552
# Collection
# Tapework
# epoch:  436  ; KL:  0.0072643603  ; LR:  0.0041279932  ; EPSILON:  0.12929533692197187
# Collection
# Tapework
# epoch:  437  ; KL:  0.005348823  ; LR:  0.0041259932  ; EPSILON:  0.1291660415850499
# Collection
# Tapework
# epoch:  438  ; KL:  0.012623874  ; LR:  0.004123993  ; EPSILON:  0.12903687554346485
# Collection
# Tapework
# epoch:  439  ; KL:  0.0060849483  ; LR:  0.004121993  ; EPSILON:  0.12890783866792138
# Collection
# Tapework
# epoch:  440  ; KL:  0.0049567497  ; LR:  0.004119993  ; EPSILON:  0.12877893082925346
# Collection
# Tapework
# epoch:  441  ; KL:  0.03241725  ; LR:  0.004117993  ; EPSILON:  0.12865015189842421
# Collection
# Tapework
# epoch:  442  ; KL:  0.0022085183  ; LR:  0.004115993  ; EPSILON:  0.1285215017465258
# Collection
# Tapework
# epoch:  443  ; KL:  0.012033852  ; LR:  0.004113993  ; EPSILON:  0.12839298024477927
# Collection
# Tapework
# epoch:  444  ; KL:  0.034394767  ; LR:  0.004111993  ; EPSILON:  0.1282645872645345
# Collection
# Tapework
# epoch:  445  ; KL:  0.030799871  ; LR:  0.004109993  ; EPSILON:  0.12813632267726996
# Collection
# Tapework
# epoch:  446  ; KL:  0.010810767  ; LR:  0.004107993  ; EPSILON:  0.12800818635459268
# Collection
# Tapework
# epoch:  447  ; KL:  0.00165572  ; LR:  0.004105993  ; EPSILON:  0.1278801781682381
# Collection
# Tapework
# epoch:  448  ; KL:  0.030686948  ; LR:  0.004103993  ; EPSILON:  0.12775229799006987
# Collection
# Tapework
# epoch:  449  ; KL:  0.034386065  ; LR:  0.004101993  ; EPSILON:  0.12762454569207982
# Collection
# Tapework
# epoch:  450  ; KL:  0.0108803315  ; LR:  0.004099993  ; EPSILON:  0.12749692114638775
# Collection
# Tapework
# epoch:  451  ; KL:  0.0037695565  ; LR:  0.004097993  ; EPSILON:  0.12736942422524136
# Collection
# Tapework
# epoch:  452  ; KL:  0.014858742  ; LR:  0.004095993  ; EPSILON:  0.1272420548010161
# Collection
# Tapework
# epoch:  453  ; KL:  0.015723687  ; LR:  0.004093993  ; EPSILON:  0.12711481274621508
# Collection
# Tapework
# epoch:  454  ; KL:  0.0072883503  ; LR:  0.004091993  ; EPSILON:  0.12698769793346887
# Collection
# Tapework
# epoch:  455  ; KL:  0.016541647  ; LR:  0.004089993  ; EPSILON:  0.1268607102355354
# Collection
# Tapework
# epoch:  456  ; KL:  0.0068193004  ; LR:  0.004087993  ; EPSILON:  0.12673384952529987
# Collection
# Tapework
# ...
# Collection
# Tapework
# epoch:  2355  ; KL:  9.8332384e-05  ; LR:  0.00028996693  ; EPSILON:  0.018956352146105374
# Collection
# Tapework
# epoch:  2356  ; KL:  0.0001508611  ; LR:  0.00028796695  ; EPSILON:  0.01893739579395927
# Collection
# Tapework
# epoch:  2357  ; KL:  0.0001396405  ; LR:  0.00028596696  ; EPSILON:  0.01891845839816531
# Collection
# Tapework
# epoch:  2358  ; KL:  4.9684804e-05  ; LR:  0.00028396698  ; EPSILON:  0.018899539939767142
# Collection
# Tapework
# epoch:  2359  ; KL:  0.0003371873  ; LR:  0.000281967  ; EPSILON:  0.018880640399827377
# Collection
# Tapework
# epoch:  2360  ; KL:  3.9706272e-05  ; LR:  0.000279967  ; EPSILON:  0.01886175975942755
# Collection
# Tapework
# epoch:  2361  ; KL:  4.8385285e-05  ; LR:  0.00027796702  ; EPSILON:  0.018842897999668123
# Collection
# Tapework
# epoch:  2362  ; KL:  0.0003850994  ; LR:  0.00027596703  ; EPSILON:  0.018824055101668454
# Collection
# Tapework
# epoch:  2363  ; KL:  3.428377e-05  ; LR:  0.00027396705  ; EPSILON:  0.018805231046566787
# Collection
# Tapework
# epoch:  2364  ; KL:  5.6031637e-05  ; LR:  0.00027196706  ; EPSILON:  0.01878642581552022
# Collection
# Tapework
# epoch:  2365  ; KL:  1.2577644e-05  ; LR:  0.00026996707  ; EPSILON:  0.018767639389704698
# Collection
# Tapework
# epoch:  2366  ; KL:  0.00022591415  ; LR:  0.0002679671  ; EPSILON:  0.018748871750314994
# Collection
# Tapework
# epoch:  2367  ; KL:  0.00010118208  ; LR:  0.0002659671  ; EPSILON:  0.01873012287856468
# Collection
# Tapework
# epoch:  2368  ; KL:  0.00014772646  ; LR:  0.00026396711  ; EPSILON:  0.018711392755686118
# Collection
# Tapework
# epoch:  2369  ; KL:  9.227867e-05  ; LR:  0.00026196713  ; EPSILON:  0.01869268136293043
# Collection
# Tapework
# epoch:  2370  ; KL:  0.00023075262  ; LR:  0.00025996714  ; EPSILON:  0.0186739886815675
# Collection
# Tapework
# epoch:  2371  ; KL:  0.00017675803  ; LR:  0.00025796716  ; EPSILON:  0.018655314692885932
# Collection
# Tapework
# epoch:  2372  ; KL:  0.000183843  ; LR:  0.00025596717  ; EPSILON:  0.018636659378193046
# Collection
# Tapework
# epoch:  2373  ; KL:  5.78227e-05  ; LR:  0.00025396718  ; EPSILON:  0.018618022718814853
# Collection
# Tapework
# epoch:  2374  ; KL:  0.00021518212  ; LR:  0.0002519672  ; EPSILON:  0.01859940469609604
# Collection
# Tapework
# epoch:  2375  ; KL:  8.3099185e-05  ; LR:  0.0002499672  ; EPSILON:  0.01858080529139994
# Collection
# Tapework
# epoch:  2376  ; KL:  0.00020405863  ; LR:  0.00024796723  ; EPSILON:  0.01856222448610854
# Collection
# Tapework
# epoch:  2377  ; KL:  6.4731255e-05  ; LR:  0.00024596724  ; EPSILON:  0.01854366226162243
# Collection
# Tapework
# epoch:  2378  ; KL:  9.4184725e-05  ; LR:  0.00024396724  ; EPSILON:  0.018525118599360808
# Collection
# Tapework
# epoch:  2379  ; KL:  5.9116024e-05  ; LR:  0.00024196724  ; EPSILON:  0.018506593480761446
# Collection
# Tapework
# epoch:  2380  ; KL:  8.464179e-05  ; LR:  0.00023996724  ; EPSILON:  0.018488086887280684
# Collection
# Tapework
# epoch:  2381  ; KL:  0.00047520077  ; LR:  0.00023796724  ; EPSILON:  0.018469598800393405
# Collection
# Tapework
# epoch:  2382  ; KL:  0.0002131258  ; LR:  0.00023596724  ; EPSILON:  0.01845112920159301
# Collection
# Tapework
# epoch:  2383  ; KL:  0.00012656719  ; LR:  0.00023396724  ; EPSILON:  0.018432678072391417
# Collection
# Tapework
# epoch:  2384  ; KL:  4.8581587e-06  ; LR:  0.00023196723  ; EPSILON:  0.018414245394319025
# Collection
# Tapework
# epoch:  2385  ; KL:  3.9668488e-05  ; LR:  0.00022996723  ; EPSILON:  0.018395831148924704
# Collection
# Tapework
# epoch:  2386  ; KL:  8.1905564e-05  ; LR:  0.00022796723  ; EPSILON:  0.01837743531777578
# Collection
# Tapework
# epoch:  2387  ; KL:  0.00021156638  ; LR:  0.00022596723  ; EPSILON:  0.018359057882458004
# Collection
# Tapework
# epoch:  2388  ; KL:  0.00014764724  ; LR:  0.00022396723  ; EPSILON:  0.018340698824575546
# Collection
# Tapework
# epoch:  2389  ; KL:  0.00069404335  ; LR:  0.00022196723  ; EPSILON:  0.01832235812575097
# Collection
# Tapework
# epoch:  2390  ; KL:  0.00040194986  ; LR:  0.00021996723  ; EPSILON:  0.018304035767625217
# Collection
# Tapework
# epoch:  2391  ; KL:  0.00025487875  ; LR:  0.00021796723  ; EPSILON:  0.01828573173185759
# Collection
# Tapework
# epoch:  2392  ; KL:  8.607314e-05  ; LR:  0.00021596723  ; EPSILON:  0.018267446000125732
# Collection
# Tapework
# epoch:  2393  ; KL:  0.0001376605  ; LR:  0.00021396723  ; EPSILON:  0.018249178554125608
# Collection
# Tapework
# epoch:  2394  ; KL:  0.00012760959  ; LR:  0.00021196723  ; EPSILON:  0.018230929375571484
# Collection
# Tapework
# epoch:  2395  ; KL:  0.00027528923  ; LR:  0.00020996723  ; EPSILON:  0.018212698446195913
# Collection
# Tapework
# epoch:  2396  ; KL:  1.7118013e-05  ; LR:  0.00020796723  ; EPSILON:  0.018194485747749716
# Collection
# Tapework
# epoch:  2397  ; KL:  7.3470976e-05  ; LR:  0.00020596723  ; EPSILON:  0.018176291262001966
# Collection
# Tapework
# epoch:  2398  ; KL:  0.00016208674  ; LR:  0.00020396723  ; EPSILON:  0.018158114970739964
# Collection
# Tapework
# epoch:  2399  ; KL:  0.00010345534  ; LR:  0.00020196722  ; EPSILON:  0.018139956855769225
# Collection
# Tapework
# epoch:  2400  ; KL:  2.3517681e-05  ; LR:  0.00019996722  ; EPSILON:  0.018121816898913456
# Collection
# Tapework
# epoch:  2401  ; KL:  3.099282e-05  ; LR:  0.00019796722  ; EPSILON:  0.018103695082014544
# Collection
# Tapework
# epoch:  2402  ; KL:  2.9157618e-06  ; LR:  0.00019596722  ; EPSILON:  0.01808559138693253
# Collection
# Tapework
# epoch:  2403  ; KL:  2.0589223e-05  ; LR:  0.00019396722  ; EPSILON:  0.018067505795545596
# Collection
# Tapework
# epoch:  2404  ; KL:  3.0318313e-05  ; LR:  0.00019196722  ; EPSILON:  0.01804943828975005
# Collection
# Tapework
# epoch:  2405  ; KL:  2.746264e-05  ; LR:  0.00018996722  ; EPSILON:  0.0180313888514603
# Collection
# Tapework
# epoch:  2406  ; KL:  4.4362732e-05  ; LR:  0.00018796722  ; EPSILON:  0.01801335746260884
# Collection
# Tapework
# epoch:  2407  ; KL:  4.090316e-05  ; LR:  0.00018596722  ; EPSILON:  0.017995344105146232
# Collection
# Tapework
# epoch:  2408  ; KL:  2.4430568e-05  ; LR:  0.00018396722  ; EPSILON:  0.017977348761041085
# Collection
# Tapework
# epoch:  2409  ; KL:  2.9146899e-05  ; LR:  0.00018196722  ; EPSILON:  0.017959371412280045
# Collection
# Tapework
# epoch:  2410  ; KL:  0.0001701668  ; LR:  0.00017996722  ; EPSILON:  0.017941412040867764
# Collection
# Tapework
# epoch:  2411  ; KL:  0.00022620533  ; LR:  0.00017796722  ; EPSILON:  0.017923470628826897
# Collection
# Tapework
# epoch:  2412  ; KL:  0.00014331001  ; LR:  0.00017596722  ; EPSILON:  0.01790554715819807
# Collection
# Tapework
# epoch:  2413  ; KL:  0.00031853202  ; LR:  0.00017396722  ; EPSILON:  0.01788764161103987
# Collection
# Tapework
# epoch:  2414  ; KL:  1.6163749e-05  ; LR:  0.00017196721  ; EPSILON:  0.01786975396942883
# Collection
# Tapework
# epoch:  2415  ; KL:  3.119851e-05  ; LR:  0.00016996721  ; EPSILON:  0.017851884215459402
# Collection
# Tapework
# epoch:  2416  ; KL:  2.5675918e-05  ; LR:  0.00016796721  ; EPSILON:  0.01783403233124394
# Collection
# Tapework
# epoch:  2417  ; KL:  7.36981e-05  ; LR:  0.00016596721  ; EPSILON:  0.0178161982989127
# Collection
# Tapework
# epoch:  2418  ; KL:  5.7738882e-05  ; LR:  0.00016396721  ; EPSILON:  0.017798382100613786
# Collection
# Tapework
# epoch:  2419  ; KL:  2.3365781e-05  ; LR:  0.00016196721  ; EPSILON:  0.01778058371851317
# Collection
# Tapework
# epoch:  2420  ; KL:  1.3116367e-05  ; LR:  0.00015996721  ; EPSILON:  0.01776280313479466
# Collection
# Tapework
# epoch:  2421  ; KL:  3.1652803e-06  ; LR:  0.00015796721  ; EPSILON:  0.017745040331659863
# Collection
# Tapework
# epoch:  2422  ; KL:  7.1037866e-05  ; LR:  0.00015596721  ; EPSILON:  0.0177272952913282
# Collection
# Tapework
# epoch:  2423  ; KL:  5.5514654e-05  ; LR:  0.00015396721  ; EPSILON:  0.017709567996036873
# Collection
# Tapework
# epoch:  2424  ; KL:  8.9929265e-05  ; LR:  0.00015196721  ; EPSILON:  0.017691858428040837
# Collection
# Tapework
# epoch:  2425  ; KL:  0.00050912093  ; LR:  0.0001499672  ; EPSILON:  0.017674166569612796
# Collection
# Tapework
# epoch:  2426  ; KL:  0.00015041578  ; LR:  0.0001479672  ; EPSILON:  0.01765649240304318
# Collection
# Tapework
# epoch:  2427  ; KL:  0.00010002857  ; LR:  0.0001459672  ; EPSILON:  0.017638835910640138
# Collection
# Tapework
# epoch:  2428  ; KL:  3.1583848e-05  ; LR:  0.0001439672  ; EPSILON:  0.0176211970747295
# Collection
# Tapework
# epoch:  2429  ; KL:  2.8116932e-05  ; LR:  0.0001419672  ; EPSILON:  0.017603575877654768
# Collection
# Tapework
# epoch:  2430  ; KL:  6.7047625e-07  ; LR:  0.0001399672  ; EPSILON:  0.017585972301777112
# Collection
# Tapework
# epoch:  2431  ; KL:  1.2783067e-06  ; LR:  0.0001379672  ; EPSILON:  0.017568386329475334
# Collection
# Tapework
# epoch:  2432  ; KL:  3.5206654e-06  ; LR:  0.0001359672  ; EPSILON:  0.01755081794314586
# Collection
# Tapework
# epoch:  2433  ; KL:  2.1365528e-05  ; LR:  0.0001339672  ; EPSILON:  0.017533267125202714
# Collection
# Tapework
# epoch:  2434  ; KL:  1.7535398e-05  ; LR:  0.0001319672  ; EPSILON:  0.01751573385807751
# Collection
# Tapework
# epoch:  2435  ; KL:  1.3558213e-05  ; LR:  0.0001299672  ; EPSILON:  0.017498218124219433
# Collection
# Tapework
# epoch:  2436  ; KL:  8.605192e-06  ; LR:  0.0001279672  ; EPSILON:  0.017480719906095215
# Collection
# Tapework
# epoch:  2437  ; KL:  4.2861706e-05  ; LR:  0.0001259672  ; EPSILON:  0.017463239186189118
# Collection
# Tapework
# epoch:  2438  ; KL:  3.3117944e-05  ; LR:  0.0001239672  ; EPSILON:  0.017445775947002928
# Collection
# Tapework
# epoch:  2439  ; KL:  2.1306076e-05  ; LR:  0.0001219672  ; EPSILON:  0.017428330171055925
# Collection
# Tapework
# epoch:  2440  ; KL:  1.5710006e-05  ; LR:  0.0001199672  ; EPSILON:  0.017410901840884868
# Collection
# Tapework
# epoch:  2441  ; KL:  3.640597e-06  ; LR:  0.000117967196  ; EPSILON:  0.017393490939043982
# Collection
# Tapework
# epoch:  2442  ; KL:  2.1871598e-05  ; LR:  0.000115967196  ; EPSILON:  0.01737609744810494
# Collection
# Tapework
# epoch:  2443  ; KL:  1.0772551e-05  ; LR:  0.000113967195  ; EPSILON:  0.017358721350656834
# Collection
# Tapework
# epoch:  2444  ; KL:  1.4909904e-06  ; LR:  0.000111967194  ; EPSILON:  0.017341362629306176
# Collection
# Tapework
# epoch:  2445  ; KL:  1.0433017e-05  ; LR:  0.00010996719  ; EPSILON:  0.01732402126667687
# Collection
# Tapework
# epoch:  2446  ; KL:  1.7270141e-06  ; LR:  0.00010796719  ; EPSILON:  0.01730669724541019
# Collection
# Tapework
# epoch:  2447  ; KL:  1.17294185e-05  ; LR:  0.00010596719  ; EPSILON:  0.017289390548164783
# Collection
# Tapework
# epoch:  2448  ; KL:  5.2434602e-06  ; LR:  0.00010396719  ; EPSILON:  0.01727210115761662
# Collection
# Tapework
# epoch:  2449  ; KL:  1.8490364e-06  ; LR:  0.00010196719  ; EPSILON:  0.017254829056459003
# Collection
# Tapework
# epoch:  2450  ; KL:  1.1832891e-05  ; LR:  9.996719e-05  ; EPSILON:  0.017237574227402543
# Collection
# Tapework
# epoch:  2451  ; KL:  4.2597553e-06  ; LR:  9.796719e-05  ; EPSILON:  0.01722033665317514
# Collection
# Tapework
# epoch:  2452  ; KL:  4.9350215e-06  ; LR:  9.596719e-05  ; EPSILON:  0.017203116316521966
# Collection
# Tapework
# epoch:  2453  ; KL:  1.46387565e-05  ; LR:  9.396719e-05  ; EPSILON:  0.017185913200205443
# Collection
# Tapework
# epoch:  2454  ; KL:  5.3946947e-05  ; LR:  9.196719e-05  ; EPSILON:  0.017168727287005237
# Collection
# Tapework
# epoch:  2455  ; KL:  4.669507e-05  ; LR:  8.996719e-05  ; EPSILON:  0.01715155855971823
# Collection
# Tapework
# epoch:  2456  ; KL:  3.87591e-05  ; LR:  8.7967186e-05  ; EPSILON:  0.01713440700115851
# Collection
# Tapework
# epoch:  2457  ; KL:  3.4717577e-05  ; LR:  8.5967185e-05  ; EPSILON:  0.017117272594157355
# Collection
# Tapework
# epoch:  2458  ; KL:  1.2022728e-05  ; LR:  8.3967185e-05  ; EPSILON:  0.0171001553215632
# Collection
# Tapework
# epoch:  2459  ; KL:  1.2771968e-05  ; LR:  8.1967184e-05  ; EPSILON:  0.017083055166241635
# Collection
# Tapework
# epoch:  2460  ; KL:  2.5821242e-05  ; LR:  7.996718e-05  ; EPSILON:  0.017065972111075394
# Collection
# Tapework
# epoch:  2461  ; KL:  5.426813e-05  ; LR:  7.796718e-05  ; EPSILON:  0.01704890613896432
# Collection
# Tapework
# epoch:  2462  ; KL:  8.60926e-05  ; LR:  7.596718e-05  ; EPSILON:  0.017031857232825354
# Collection
# Tapework
# epoch:  2463  ; KL:  1.76865e-05  ; LR:  7.396718e-05  ; EPSILON:  0.017014825375592527
# Collection
# Tapework
# epoch:  2464  ; KL:  2.251516e-05  ; LR:  7.196718e-05  ; EPSILON:  0.016997810550216933
# Collection
# Tapework
# epoch:  2465  ; KL:  1.4664605e-05  ; LR:  6.996718e-05  ; EPSILON:  0.016980812739666715
# Collection
# Tapework
# epoch:  2466  ; KL:  4.6122136e-06  ; LR:  6.796718e-05  ; EPSILON:  0.016963831926927048
# Collection
# Tapework
# epoch:  2467  ; KL:  1.3729444e-05  ; LR:  6.596718e-05  ; EPSILON:  0.01694686809500012
# Collection
# Tapework
# epoch:  2468  ; KL:  2.3150702e-05  ; LR:  6.396718e-05  ; EPSILON:  0.01692992122690512
# Collection
# Tapework
# epoch:  2469  ; KL:  1.9028288e-05  ; LR:  6.196718e-05  ; EPSILON:  0.016912991305678214
# Collection
# Tapework
# epoch:  2470  ; KL:  1.5839136e-05  ; LR:  5.9967177e-05  ; EPSILON:  0.016896078314372537
# Collection
# Tapework
# epoch:  2471  ; KL:  1.6192535e-05  ; LR:  5.7967176e-05  ; EPSILON:  0.016879182236058166
# Collection
# Tapework
# epoch:  2472  ; KL:  3.158856e-06  ; LR:  5.5967175e-05  ; EPSILON:  0.01686230305382211
# Collection
# Tapework
# epoch:  2473  ; KL:  2.9976422e-06  ; LR:  5.3967175e-05  ; EPSILON:  0.016845440750768288
# Collection
# Tapework
# epoch:  2474  ; KL:  1.6276098e-06  ; LR:  5.1967174e-05  ; EPSILON:  0.01682859531001752
# Collection
# Tapework
# epoch:  2475  ; KL:  1.1503545e-06  ; LR:  4.9967173e-05  ; EPSILON:  0.016811766714707504
# Collection
# Tapework
# epoch:  2476  ; KL:  7.206916e-07  ; LR:  4.7967173e-05  ; EPSILON:  0.016794954947992796
# Collection
# Tapework
# epoch:  2477  ; KL:  2.0619862e-06  ; LR:  4.5967172e-05  ; EPSILON:  0.016778159993044803
# Collection
# Tapework
# epoch:  2478  ; KL:  8.943738e-07  ; LR:  4.396717e-05  ; EPSILON:  0.01676138183305176
# Collection
# Tapework
# epoch:  2479  ; KL:  4.6003535e-07  ; LR:  4.196717e-05  ; EPSILON:  0.016744620451218706
# Collection
# Tapework
# epoch:  2480  ; KL:  1.1211413e-06  ; LR:  3.996717e-05  ; EPSILON:  0.01672787583076749
# Collection
# Tapework
# epoch:  2481  ; KL:  1.2263048e-06  ; LR:  3.796717e-05  ; EPSILON:  0.016711147954936723
# Collection
# Tapework
# epoch:  2482  ; KL:  2.6137852e-06  ; LR:  3.596717e-05  ; EPSILON:  0.016694436806981787
# Collection
# Tapework
# epoch:  2483  ; KL:  2.7696774e-06  ; LR:  3.3967168e-05  ; EPSILON:  0.016677742370174806
# Collection
# Tapework
# epoch:  2484  ; KL:  4.399416e-06  ; LR:  3.1967167e-05  ; EPSILON:  0.01666106462780463
# Collection
# Tapework
# epoch:  2485  ; KL:  9.03668e-06  ; LR:  2.9967166e-05  ; EPSILON:  0.016644403563176827
# Collection
# Tapework
# epoch:  2486  ; KL:  1.2447906e-05  ; LR:  2.7967166e-05  ; EPSILON:  0.01662775915961365
# Collection
# Tapework
# epoch:  2487  ; KL:  6.1623145e-06  ; LR:  2.5967165e-05  ; EPSILON:  0.016611131400454036
# Collection
# Tapework
# epoch:  2488  ; KL:  3.3334506e-06  ; LR:  2.3967164e-05  ; EPSILON:  0.016594520269053583
# Collection
# Tapework
# epoch:  2489  ; KL:  3.0099966e-06  ; LR:  2.1967164e-05  ; EPSILON:  0.016577925748784528
# Collection
# Tapework
# epoch:  2490  ; KL:  1.8455203e-06  ; LR:  1.9967163e-05  ; EPSILON:  0.016561347823035744
# Collection
# Tapework
# epoch:  2491  ; KL:  2.503167e-07  ; LR:  1.7967162e-05  ; EPSILON:  0.01654478647521271
# Collection
# Tapework
# epoch:  2492  ; KL:  1.5509372e-07  ; LR:  1.5967162e-05  ; EPSILON:  0.016528241688737497
# Collection
# Tapework
# epoch:  2493  ; KL:  3.7032427e-07  ; LR:  1.3967162e-05  ; EPSILON:  0.01651171344704876
# Collection
# Tapework
# epoch:  2494  ; KL:  3.3451586e-09  ; LR:  1.1967162e-05  ; EPSILON:  0.01649520173360171
# Collection
# Tapework
# epoch:  2495  ; KL:  2.8220975e-07  ; LR:  9.967162e-06  ; EPSILON:  0.01647870653186811
# Collection
# Tapework
# epoch:  2496  ; KL:  3.0250877e-07  ; LR:  7.967163e-06  ; EPSILON:  0.016462227825336243
# Collection
# Tapework
# epoch:  2497  ; KL:  1.1586413e-07  ; LR:  5.967163e-06  ; EPSILON:  0.016445765597510906
# Collection
# Tapework
# epoch:  2498  ; KL:  5.4396843e-08  ; LR:  3.967163e-06  ; EPSILON:  0.016429319831913397
# Collection
# Tapework
# epoch:  2499  ; KL:  3.0410534e-09  ; LR:  1.9671631e-06  ; EPSILON:  0.016412890512081484
# Collection
# Tapework

# %%
test_env = gym.make('LunarLander-v2', render_mode='human')
#test_env = gym.make('CartPole-v1', render_mode='human')
obs, inf = test_env.reset()

# %%
for i in range(1000):
    qs = pi(tf.expand_dims(obs, 0))
    act = np.argmax(qs)
    obs, _, terminated, _, _ = test_env.step(act)
    if(terminated):
        obs, _ = test_env.reset()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# obsolete implementation of rewards-to-go and advantages that more closely follows the pseudocode on spinning up
def basic_advantages():
    # 4: Compute rewards-to-go R̂_t
    rewards_to_go = np.zeros_like(D["rewards"])
    # Most environments will not be terminated at the last step. We estimate the rest-reward after the last step
    # as the value function for the next observation.
    rewards_to_go[:,-1] = D["rewards"][:,-1] + V(ensuing_observation) * (1-D["terminateds"][:,-1])
    for ind in reversed(range(1,STEPS_PER_TRAJECTORY)):
        # The reward_to_go is the sum of all rewards until the episode ended
        rewards_to_go[:,ind-1] += D["rewards"][:,ind-1] + rewards_to_go[:,ind] * (1-D["terminateds"][:,ind-1])

    # flatten data
    rewards_to_go = np.reshape(rewards_to_go, (-1, *rewards_to_go.shape[2:]))
    for key, val in D.items():
        D[key] = np.reshape(val, (-1, *val.shape[2:]))

    # 5: Compute advantage estimates, Â_t (using any method of advantage estimation) based on the current value function V_Φ_k
    values = tf.reshape(V(D["observations"]), -1)
    advantages = rewards_to_go - values
    # zero center advantages
    advantages = advantages - tf.reduce_mean(advantages)
