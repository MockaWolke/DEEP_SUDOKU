# %%
import numpy as np 
import pandas as pd
import deepsudoku
import gymnasium

# %%
env = gymnasium.make('Sudoku-v0', render_mode = "human", upper_bound_missing_digist = 1)
env.reset()
env.render()

# %%
env.step(np.zeros((3,), np.int32))

# %%
env = gymnasium.make_vec('Sudoku-v0', 5)
env.action_space
# Out:
# Tuple(MultiDiscrete([9 9 9 9 9]), MultiDiscrete([9 9 9 9 9]), MultiDiscrete([9 9 9 9 9], start=[1 1 1 1 1]))

# %%
# %%timeit
actions = np.ones((3,5), np.int32)
obs, rewards, terminated, _, _= env.step(actions)
# Out:
# 42.1 ms ± 4.35 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
