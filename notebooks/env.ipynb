# %%
import numpy as np 
import pandas as pd
import deepsudoku.reinforcement_learning
import gymnasium
# Out:
# Sudoku Environment avaible at gymnasium as 'Sudoku-v0'.

# %%
env = gymnasium.make('Sudoku-v0', render_mode = "human", upper_bound_missing_digist = 1)
env.reset()
env.render()

# %%
env.step(np.zeros((3,), np.int32))
# Out:
# (array([[7, 8, 6, 2, 1, 3, 9, 4, 5],
#         [4, 5, 2, 8, 7, 9, 1, 6, 3],
#         [3, 9, 1, 4, 5, 6, 7, 8, 2],
#         [6, 7, 8, 1, 4, 2, 5, 3, 9],
#         [9, 2, 3, 6, 8, 5, 4, 0, 1],
#         [5, 1, 4, 3, 9, 7, 6, 2, 8],
#         [2, 6, 5, 7, 3, 1, 8, 9, 4],
#         [8, 3, 9, 5, 6, 4, 2, 1, 7],
#         [1, 4, 7, 9, 2, 8, 3, 5, 6]], dtype=int32),
#  -1,
#  True,
#  False,
#  {})

# %%
env = gymnasium.make_vec('Sudoku-v0', 5)
env.reset()
env.action_space
# Out:
# Tuple(MultiDiscrete([9 9 9 9 9]), MultiDiscrete([9 9 9 9 9]), MultiDiscrete([9 9 9 9 9]))

# %%
# %%timeit
actions = np.ones((3,5), np.int32)
obs, rewards, terminated, _, _= env.step(actions)
# Out:
# 65.3 ms ± 10.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
