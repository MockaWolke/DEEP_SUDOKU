# %%
import numpy as np 
import pandas as pd
import deepsudoku.reinforcement_learning
import gymnasium
import random
random.seed(0)
# Out:
# Registered Sudoku Environments

# %%
env = gymnasium.make('Sudoku-nostop0', render_mode = "human", upper_bound_missing_digist = 1, cut_off_limit = 10)
env.reset()
env.render()
env.action_space.nvec
# Out:
# array([9, 9, 9])

# %%
# %%timeit
env.reset()
# Out:
# 635 µs ± 25.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
env.step((1,2,0))
# Out:
# (array([[7, 5, 9, 3, 4, 1, 8, 2, 6],
#         [0, 4, 8, 9, 2, 7, 5, 1, 3],
#         [2, 1, 3, 5, 6, 8, 7, 9, 4],
#         [9, 3, 4, 1, 5, 6, 2, 8, 7],
#         [1, 7, 2, 8, 3, 9, 4, 6, 5],
#         [8, 6, 5, 2, 7, 4, 9, 3, 1],
#         [4, 2, 1, 6, 9, 5, 3, 7, 8],
#         [3, 8, 7, 4, 1, 2, 6, 5, 9],
#         [5, 9, 6, 7, 8, 3, 1, 4, 2]], dtype=int32),
#  -0.1,
#  False,
#  False,
#  {})

# %%
envs = gymnasium.make_vec('Sudoku-nostop0',20,)

# %%
# %%timeit
envs.reset()
# Out:
# 6.01 ms ± 156 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
actions = np.ones((20,3), np.int32)
obs, rewards, terminated, _, _= envs.step(actions)
# Out:
# 1.52 ms ± 115 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
