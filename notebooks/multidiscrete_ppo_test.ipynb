# %%
from deepsudoku import REPO_PATH, DIFFICULTIES
import os
os.chdir(REPO_PATH)

import tensorflow as tf
import numpy as np
from deepsudoku.reinforcement_learning.ppo import *

import gymnasium as gym
from deepsudoku.verify_sudoku import *
# Out:
# 2023-08-25 17:41:13.235447: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sudoku Environment avaible at gymnasium as 'Sudoku-v0'.

# %%
import random

class PPO_MultiDiscrete_Cartpole_Wrapper:
    def __init__(self, NUM_ENVS, **env_kwargs):
        self.num_envs = NUM_ENVS
        # We use vectorized environments (Implementation Detail 1)
        self.envs = envs = gym.vector.make('CartPole-v1', num_envs=NUM_ENVS)
        self.current_state, _ = self.envs.reset()

    def sample(self, model):
        old_observation = self.current_state
        q_values = model(self.current_state) #get q values for current state
        #Q_values are logprobs, we use a categorical distribution to sample
        probs = np.exp(q_values)
        # Implementing Multi-Discrete Action spaces:
        # probs = [environments][action-spaces][logprobs]
        # We need to sample for each environment from all action-spaces
        # NOTE: This assumes that all action-spaces look like [0,1,2,3,...]
        # In particular, for the sudoku case, the third action space represents the number we want to fill in
        # This number will be one less than the actual digit that gets filled in
        # This is accounted for and implemented like this in our custom environment
        action = np.array([
                    [np.random.choice(np.arange(len(logprob)), p=logprob) for logprob in action_space]
                    for action_space in probs
                 ])

        log_prob = tf.gather(q_values, action, batch_dims=2)
        log_prob = tf.reduce_sum(log_prob, axis=-1).numpy()

        new_observation, reward, terminated, _, _ = self.envs.step(action[:,0])

        self.current_state = new_observation #update current state after environment did step
        return (old_observation, action, reward, new_observation, terminated, log_prob)
    
    def collect_trajectories(self, model, length):
        old_obs, act, rew, new_obs, term, log_probs = self.sample(model)
        data = {"observations": np.expand_dims(old_obs, axis=1), 
                "actions": np.expand_dims(act, axis=1), 
                "rewards": rew, 
                "terminateds": term,
                "log_prob": log_probs}
        for i in range(length-1):
            old_obs, act, rew, new_obs, term, log_probs = self.sample(model)
            data["observations"] = np.column_stack((data["observations"], np.expand_dims(old_obs, axis=1)))
            data["actions"] = np.column_stack((data["actions"], np.expand_dims(act, axis=1)))
            data["rewards"] = np.column_stack((data["rewards"], rew))
            data["terminateds"] = np.column_stack((data["terminateds"], term))
            data["log_prob"] = np.column_stack((data["log_prob"], log_probs))
        return data, new_obs

# %%
envs = PPO_MultiDiscrete_Cartpole_Wrapper(5)

# %%
# Create models

# Implementation Detail 2: Orthogonal Initialization of hidden weights and constant initialization of biases and output weights
# Biases seem to be 0 by default in Keras
hidden_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=np.sqrt(2))
pol_out_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=0.01)
val_out_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=1)

def create_policy_model():
    inputs = tf.keras.Input(shape=(4))
    x = tf.keras.layers.Flatten()(inputs)
    x = tf.keras.layers.Dense(128, activation="tanh", kernel_initializer=hidden_ortho_init())(x)
    x = tf.keras.layers.Dense(128, activation="tanh", kernel_initializer=hidden_ortho_init())(x)
    x = tf.keras.layers.Dense(2, activation="log_softmax", kernel_initializer=pol_out_ortho_init())(x)
    outputs = tf.keras.layers.Reshape((1,2))(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="pi")
    return model

def create_value_function_model():
    inputs = tf.keras.Input(shape=(4))
    x = tf.keras.layers.Flatten()(inputs)
    x = tf.keras.layers.Dense(32, activation="relu", kernel_initializer=hidden_ortho_init())(x)
    #x = tf.keras.layers.Dense(32, activation="relu", kernel_initializer=hidden_ortho_init())(x)
    outputs = tf.keras.layers.Dense(1, activation="linear", kernel_initializer=val_out_ortho_init())(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="V")
    return model

# %%
pi, V = PPO(envs, create_policy_model(), create_value_function_model(), TRAIN_EPOCHS = 1000, LEARNING_RATE_DECAY_PER_EPOCH = 0, LEARNING_RATE_START=0.001)
# Out:
# 2023-08-25 17:41:18.637277: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# epoch:  0  ; KL:  0  ; LR:  0.001  ; MR:  0
# Collection
# Tapework
# epoch:  1  ; KL:  0.0018327674  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  2  ; KL:  0.004429827  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  3  ; KL:  0.0020111117  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  4  ; KL:  0.0027630597  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  5  ; KL:  0.00218419  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  6  ; KL:  0.0030257185  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  7  ; KL:  0.0028139409  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  8  ; KL:  0.0015623911  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  9  ; KL:  0.002095902  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  10  ; KL:  0.0007709952  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  11  ; KL:  0.00084699807  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  12  ; KL:  0.0022357416  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  13  ; KL:  0.001324426  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  14  ; KL:  0.0059280717  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  15  ; KL:  0.00047876337  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  16  ; KL:  0.0008329977  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  17  ; KL:  0.0006710077  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  18  ; KL:  0.0008208475  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  19  ; KL:  0.00482007  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  20  ; KL:  0.0025672223  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  21  ; KL:  0.012149192  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  22  ; KL:  0.0013021477  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  23  ; KL:  0.00015987638  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  24  ; KL:  0.0023803283  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  25  ; KL:  0.0009888674  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  26  ; KL:  7.448984e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  27  ; KL:  0.00060738955  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  28  ; KL:  0.0042294147  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  29  ; KL:  0.00075184024  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  30  ; KL:  8.048649e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  31  ; KL:  0.0002671585  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  32  ; KL:  0.0014497692  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  33  ; KL:  0.0010456879  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  34  ; KL:  0.00071571424  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  35  ; KL:  0.00017118081  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  36  ; KL:  0.00046117208  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  37  ; KL:  0.0004411764  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  38  ; KL:  0.00015662565  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  39  ; KL:  0.0021058028  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  40  ; KL:  0.0006745766  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  41  ; KL:  0.0076064323  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  42  ; KL:  0.00031696702  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  43  ; KL:  0.00041066096  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  44  ; KL:  0.0016668596  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  45  ; KL:  0.0019022122  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  46  ; KL:  0.001697203  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  47  ; KL:  0.0065504606  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  48  ; KL:  0.012585612  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  49  ; KL:  0.0026804458  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  50  ; KL:  0.0012293693  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  51  ; KL:  0.0010473967  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  52  ; KL:  0.0012565547  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  53  ; KL:  0.00042848487  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  54  ; KL:  3.978534e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  55  ; KL:  7.981959e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  56  ; KL:  0.00018305454  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  57  ; KL:  0.001513891  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  58  ; KL:  0.0045763976  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  59  ; KL:  0.0014351481  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  60  ; KL:  0.0027534207  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  61  ; KL:  0.007778311  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  62  ; KL:  0.0003240688  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  63  ; KL:  0.002402657  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  64  ; KL:  0.00045229832  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  65  ; KL:  0.0028594453  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  66  ; KL:  0.0010882487  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  67  ; KL:  0.00030490634  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  68  ; KL:  0.00018234886  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  69  ; KL:  0.0016018482  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  70  ; KL:  0.012300949  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  71  ; KL:  0.0024832527  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  72  ; KL:  0.000539892  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  73  ; KL:  0.0012238278  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  74  ; KL:  0.0012953471  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  75  ; KL:  0.0025333152  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  76  ; KL:  0.0014267681  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  77  ; KL:  0.0016440579  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  78  ; KL:  0.0008390262  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  79  ; KL:  0.0006025905  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  80  ; KL:  0.0038304226  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  81  ; KL:  0.0011750491  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  82  ; KL:  0.010041974  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  83  ; KL:  0.00012099247  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  84  ; KL:  0.0020026807  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  85  ; KL:  0.006784995  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  86  ; KL:  0.0008984354  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  87  ; KL:  0.0040228153  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  88  ; KL:  0.0004344348  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  89  ; KL:  0.00031763004  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  90  ; KL:  8.7813e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  91  ; KL:  0.000596079  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  92  ; KL:  0.00911306  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  93  ; KL:  0.011888925  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  94  ; KL:  0.001454243  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  95  ; KL:  0.00036664004  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  96  ; KL:  0.010365032  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  97  ; KL:  0.00025809248  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  98  ; KL:  0.00039300811  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  99  ; KL:  0.010405613  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  100  ; KL:  0.012869117  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  101  ; KL:  0.006371099  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  102  ; KL:  0.00021853948  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  103  ; KL:  8.5127445e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  104  ; KL:  0.007676135  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  105  ; KL:  0.00598081  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  106  ; KL:  0.0009015659  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  107  ; KL:  0.0009744138  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  108  ; KL:  0.0029999148  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  109  ; KL:  0.0011489256  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  110  ; KL:  0.000663161  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  111  ; KL:  0.0018555258  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  112  ; KL:  0.0017864073  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  113  ; KL:  0.004974801  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  114  ; KL:  0.00108547  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  115  ; KL:  0.0008212002  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  116  ; KL:  0.0011654325  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  117  ; KL:  0.003911741  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  118  ; KL:  0.0037572123  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  119  ; KL:  0.0002957764  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  120  ; KL:  0.0010386545  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  121  ; KL:  0.0014630642  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  122  ; KL:  0.00044106392  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  123  ; KL:  0.0072966004  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  124  ; KL:  0.005608871  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  125  ; KL:  0.0005533456  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  126  ; KL:  0.0021524597  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  127  ; KL:  0.005419843  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  128  ; KL:  0.00013503539  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  129  ; KL:  0.0030116586  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  130  ; KL:  0.010143026  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  131  ; KL:  3.2295226e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  132  ; KL:  0.003308468  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  133  ; KL:  0.0012160434  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  134  ; KL:  0.0047617303  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  135  ; KL:  3.955232e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  136  ; KL:  0.016332513  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  137  ; KL:  0.0023634573  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  138  ; KL:  0.0017179697  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  139  ; KL:  0.0017408452  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  140  ; KL:  0.0014224459  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  141  ; KL:  0.0008386733  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  142  ; KL:  0.0031777637  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  143  ; KL:  0.0007167417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  144  ; KL:  0.0071999603  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  145  ; KL:  0.00019950177  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  146  ; KL:  0.00335625  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  147  ; KL:  0.0021116715  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  148  ; KL:  0.0055243885  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  149  ; KL:  0.0014297676  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  150  ; KL:  0.0011180025  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  151  ; KL:  0.0002547884  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  152  ; KL:  2.2754377e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  153  ; KL:  0.0010868448  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  154  ; KL:  0.0009869873  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  155  ; KL:  0.000882179  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  156  ; KL:  0.0021438496  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  157  ; KL:  0.0001924676  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  158  ; KL:  0.00030435788  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  159  ; KL:  0.022937292  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  160  ; KL:  0.00038916495  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  161  ; KL:  0.008157522  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  162  ; KL:  0.0014768215  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  163  ; KL:  0.0016869742  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  164  ; KL:  0.00012788747  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  165  ; KL:  0.002006456  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  166  ; KL:  0.0011723728  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  167  ; KL:  0.001111668  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  168  ; KL:  0.00074348826  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  169  ; KL:  0.0006949164  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  170  ; KL:  0.000536187  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  171  ; KL:  0.0016858861  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  172  ; KL:  8.233591e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  173  ; KL:  0.0003469003  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  174  ; KL:  0.011576762  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  175  ; KL:  0.013003998  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  176  ; KL:  0.01356943  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  177  ; KL:  0.0017677417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  178  ; KL:  0.0023797688  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  179  ; KL:  0.0003877764  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  180  ; KL:  0.008679202  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  181  ; KL:  0.0151889045  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  182  ; KL:  0.014505012  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  183  ; KL:  0.004963595  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  184  ; KL:  0.010160664  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  185  ; KL:  0.00014256997  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  186  ; KL:  0.0011565458  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  187  ; KL:  0.0113412775  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  188  ; KL:  0.0024117837  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  189  ; KL:  0.0004796182  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  190  ; KL:  0.005118179  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  191  ; KL:  0.0010021152  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  192  ; KL:  0.0003248443  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  193  ; KL:  0.0017533944  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  194  ; KL:  0.014819738  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  195  ; KL:  0.00012661784  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  196  ; KL:  0.000948666  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  197  ; KL:  0.0017587052  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  198  ; KL:  0.0018827636  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  199  ; KL:  0.0010789915  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  200  ; KL:  0.0022642398  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  201  ; KL:  0.00015559352  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  202  ; KL:  0.007130387  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  203  ; KL:  0.0003737479  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  204  ; KL:  0.0011842716  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  205  ; KL:  8.5096864e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  206  ; KL:  0.0007682688  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  207  ; KL:  0.010030672  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  208  ; KL:  0.0007936304  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  209  ; KL:  0.012045605  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  210  ; KL:  0.011372161  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  211  ; KL:  0.0038266976  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  212  ; KL:  0.0055356626  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  213  ; KL:  0.0039958977  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  214  ; KL:  0.0023064304  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  215  ; KL:  0.0021602374  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  216  ; KL:  0.0046933363  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  217  ; KL:  0.0068841237  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  218  ; KL:  0.0016216064  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  219  ; KL:  0.00018607848  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  220  ; KL:  0.00012442903  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  221  ; KL:  0.001579902  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  222  ; KL:  0.010258716  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  223  ; KL:  0.0093524065  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  224  ; KL:  0.0015609559  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  225  ; KL:  0.00029281146  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  226  ; KL:  0.00608425  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  227  ; KL:  0.00059666985  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  228  ; KL:  0.0024208925  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  229  ; KL:  0.0006997685  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  230  ; KL:  0.00015110751  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  231  ; KL:  0.0066450415  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  232  ; KL:  9.888785e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  233  ; KL:  0.0019666678  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  234  ; KL:  0.010996927  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  235  ; KL:  0.0027333216  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  236  ; KL:  0.0018371512  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  237  ; KL:  0.004589506  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  238  ; KL:  0.00020798235  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  239  ; KL:  5.120592e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  240  ; KL:  0.0011124099  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  241  ; KL:  0.0075559337  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  242  ; KL:  0.0028459984  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  243  ; KL:  0.00292636  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  244  ; KL:  0.0034249278  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  245  ; KL:  0.0017827983  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  246  ; KL:  0.00136786  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  247  ; KL:  0.011749227  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  248  ; KL:  0.0031319566  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  249  ; KL:  0.00026216946  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  250  ; KL:  0.0012751699  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  251  ; KL:  0.0131997615  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  252  ; KL:  0.0032259158  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  253  ; KL:  0.0126405135  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  254  ; KL:  0.0019394333  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  255  ; KL:  0.0060520414  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  256  ; KL:  0.007448192  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  257  ; KL:  0.0025637078  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  258  ; KL:  0.0006517907  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  259  ; KL:  0.0001329471  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  260  ; KL:  0.00018163375  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  261  ; KL:  0.0067770584  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  262  ; KL:  1.0238856e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  263  ; KL:  0.0007548346  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  264  ; KL:  0.003228117  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  265  ; KL:  0.013944055  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  266  ; KL:  2.1415515e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  267  ; KL:  0.0063457587  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  268  ; KL:  0.0011533252  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  269  ; KL:  0.00036793895  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  270  ; KL:  0.021239908  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  271  ; KL:  0.0020458235  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  272  ; KL:  0.0001815263  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  273  ; KL:  0.0030019658  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  274  ; KL:  0.00022318492  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  275  ; KL:  0.00035587032  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  276  ; KL:  0.0024713012  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  277  ; KL:  0.003932307  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  278  ; KL:  0.0071505764  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  279  ; KL:  0.0025072081  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  280  ; KL:  0.00663353  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  281  ; KL:  0.00039219015  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  282  ; KL:  0.0024920534  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  283  ; KL:  0.010146527  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  284  ; KL:  0.0014395114  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  285  ; KL:  0.00024402997  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  286  ; KL:  0.0001346827  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  287  ; KL:  0.006098707  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  288  ; KL:  0.00051727286  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  289  ; KL:  0.0009577484  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  290  ; KL:  0.00072264107  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  291  ; KL:  0.0009224373  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  292  ; KL:  0.0035188268  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  293  ; KL:  0.007462992  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  294  ; KL:  0.00010524147  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  295  ; KL:  0.0012726055  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  296  ; KL:  0.0022303485  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  297  ; KL:  9.2077586e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  298  ; KL:  0.015306894  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  299  ; KL:  6.573895e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  300  ; KL:  0.0044696094  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  301  ; KL:  0.00338866  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  302  ; KL:  0.0017899241  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  303  ; KL:  0.004904477  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  304  ; KL:  0.00080209004  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  305  ; KL:  0.009967922  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  306  ; KL:  0.00050454045  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  307  ; KL:  0.0017292852  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  308  ; KL:  0.0044463463  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  309  ; KL:  0.0023244722  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  310  ; KL:  0.0077445228  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  311  ; KL:  0.00043739917  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  312  ; KL:  0.007249971  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  313  ; KL:  0.016460111  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  314  ; KL:  0.00339502  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  315  ; KL:  0.0012187765  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  316  ; KL:  0.0011743363  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  317  ; KL:  0.0009379066  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  318  ; KL:  0.0029141933  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  319  ; KL:  0.0013072114  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  320  ; KL:  0.0010171861  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  321  ; KL:  0.014203607  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  322  ; KL:  0.0008271969  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  323  ; KL:  0.0009923346  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  324  ; KL:  0.00010503699  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  325  ; KL:  0.0016391556  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  326  ; KL:  0.020489842  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  327  ; KL:  0.00024639093  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  328  ; KL:  0.00028155895  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  329  ; KL:  0.00013856402  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  330  ; KL:  0.00015601436  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  331  ; KL:  0.00032922937  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  332  ; KL:  0.00031039058  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  333  ; KL:  0.0005626119  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  334  ; KL:  0.0006741662  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  335  ; KL:  0.0002126428  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  336  ; KL:  0.0010395113  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  337  ; KL:  0.008613403  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  338  ; KL:  0.0006547836  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  339  ; KL:  0.0007313947  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  340  ; KL:  0.0058251168  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  341  ; KL:  0.008255879  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  342  ; KL:  0.009879073  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  343  ; KL:  0.00072393595  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  344  ; KL:  0.0026716895  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  345  ; KL:  0.0067118085  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  346  ; KL:  0.0028063825  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  347  ; KL:  0.0007509517  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  348  ; KL:  0.0045277164  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  349  ; KL:  0.0001139668  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  350  ; KL:  0.00095964666  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  351  ; KL:  0.0032343143  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  352  ; KL:  0.003615983  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  353  ; KL:  0.00093535165  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  354  ; KL:  0.0024997345  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  355  ; KL:  0.0006360901  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  356  ; KL:  8.798335e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  357  ; KL:  0.0047305925  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  358  ; KL:  0.0012626977  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  359  ; KL:  0.003963398  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  360  ; KL:  0.0065373327  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  361  ; KL:  0.00086537417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  362  ; KL:  0.015723096  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  363  ; KL:  9.382569e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  364  ; KL:  0.013918453  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  365  ; KL:  0.0002475126  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  366  ; KL:  0.00051719643  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  367  ; KL:  0.0061725173  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  368  ; KL:  0.007820577  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  369  ; KL:  0.0035217803  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  370  ; KL:  0.0028217358  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  371  ; KL:  0.0002663259  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  372  ; KL:  0.0012597463  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  373  ; KL:  0.00063812063  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  374  ; KL:  0.0014644599  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  375  ; KL:  0.007021173  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  376  ; KL:  0.00030051332  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  377  ; KL:  0.0044440664  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  378  ; KL:  0.0037906398  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  379  ; KL:  0.0006880599  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  380  ; KL:  0.0018913542  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  381  ; KL:  0.013162963  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  382  ; KL:  0.0011354954  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  383  ; KL:  0.005666677  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  384  ; KL:  0.0003795765  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  385  ; KL:  0.000322616  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  386  ; KL:  0.0060025705  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  387  ; KL:  0.0024216017  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  388  ; KL:  0.0011602615  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  389  ; KL:  0.000916991  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  390  ; KL:  0.0004583484  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  391  ; KL:  0.00037221573  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  392  ; KL:  0.0014589195  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  393  ; KL:  0.00020324458  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  394  ; KL:  0.004117938  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  395  ; KL:  0.002285881  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  396  ; KL:  0.011803754  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  397  ; KL:  0.00900526  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  398  ; KL:  0.00036205462  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  399  ; KL:  0.0001772583  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  400  ; KL:  0.0014124583  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  401  ; KL:  0.00068253506  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  402  ; KL:  0.00241503  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  403  ; KL:  0.0024493507  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  404  ; KL:  0.003240527  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  405  ; KL:  0.008852844  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  406  ; KL:  0.004996151  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  407  ; KL:  4.9834387e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  408  ; KL:  0.0044267057  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  409  ; KL:  0.010054008  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  410  ; KL:  0.00029102233  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  411  ; KL:  0.0012009132  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  412  ; KL:  0.007422696  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  413  ; KL:  5.748997e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  414  ; KL:  0.0026741945  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  415  ; KL:  0.0018748065  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  416  ; KL:  0.0023675964  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  417  ; KL:  0.00050497334  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  418  ; KL:  0.0004278043  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  419  ; KL:  0.007225915  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  420  ; KL:  0.0036727516  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  421  ; KL:  0.0027206156  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  422  ; KL:  0.0013868256  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  423  ; KL:  0.000937021  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  424  ; KL:  0.0015310172  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  425  ; KL:  0.0145263225  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  426  ; KL:  0.00046068183  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  427  ; KL:  0.00467712  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  428  ; KL:  0.0013098831  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  429  ; KL:  0.004997502  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  430  ; KL:  0.0011370113  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  431  ; KL:  0.0092311  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  432  ; KL:  0.0013158157  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  433  ; KL:  0.00013024293  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  434  ; KL:  0.00039214655  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  435  ; KL:  0.0047915005  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  436  ; KL:  0.0002869746  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  437  ; KL:  0.0011827783  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  438  ; KL:  0.00885568  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  439  ; KL:  4.939735e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  440  ; KL:  0.0027649563  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  441  ; KL:  0.0005899357  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  442  ; KL:  0.00018603585  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  443  ; KL:  0.00022819098  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  444  ; KL:  0.0042753336  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  445  ; KL:  0.00038181382  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  446  ; KL:  0.020489113  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  447  ; KL:  0.0015072867  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  448  ; KL:  0.001590327  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  449  ; KL:  0.0011174796  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  450  ; KL:  0.00092899805  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  451  ; KL:  0.00069519784  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  452  ; KL:  0.0035851242  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  453  ; KL:  0.009743435  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  454  ; KL:  0.001325371  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  455  ; KL:  0.0025317387  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  456  ; KL:  0.0013978137  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  457  ; KL:  0.0010596359  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  458  ; KL:  0.0006852632  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  459  ; KL:  0.00033010307  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  460  ; KL:  0.004855089  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  461  ; KL:  0.0036626596  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  462  ; KL:  0.0048474846  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  463  ; KL:  0.0012847848  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  464  ; KL:  0.0022266181  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  465  ; KL:  0.0020418598  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  466  ; KL:  0.00020267002  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  467  ; KL:  0.0030961228  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  468  ; KL:  0.003799689  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  469  ; KL:  0.007888864  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  470  ; KL:  0.009971615  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  471  ; KL:  0.0025155612  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  472  ; KL:  0.00020902567  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  473  ; KL:  0.0013434741  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  474  ; KL:  0.001610653  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  475  ; KL:  0.012085146  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  476  ; KL:  0.0024260324  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  477  ; KL:  0.00047402838  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  478  ; KL:  0.0002985932  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  479  ; KL:  0.0106488615  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  480  ; KL:  9.230813e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  481  ; KL:  0.004112225  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  482  ; KL:  0.014682694  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  483  ; KL:  0.00025886818  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  484  ; KL:  0.012767923  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  485  ; KL:  0.0012909725  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  486  ; KL:  0.002251008  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  487  ; KL:  0.018840417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  488  ; KL:  0.0017160415  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  489  ; KL:  0.00044802765  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  490  ; KL:  0.0008813903  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  491  ; KL:  0.001341333  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  492  ; KL:  0.00065005355  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  493  ; KL:  0.0007414706  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  494  ; KL:  0.0017649438  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  495  ; KL:  0.014781014  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  496  ; KL:  0.0019133716  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  497  ; KL:  0.010636084  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  498  ; KL:  0.014634236  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  499  ; KL:  0.010627138  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  500  ; KL:  0.00031868365  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  501  ; KL:  0.000358252  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  502  ; KL:  0.0076941117  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  503  ; KL:  0.00011377774  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  504  ; KL:  0.0007099039  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  505  ; KL:  0.0016332658  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  506  ; KL:  0.005982417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  507  ; KL:  0.00071092375  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  508  ; KL:  0.000787315  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  509  ; KL:  0.0002647977  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  510  ; KL:  0.0035049673  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  511  ; KL:  0.008458643  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  512  ; KL:  0.0056325323  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  513  ; KL:  0.0012801227  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  514  ; KL:  0.013341903  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  515  ; KL:  0.009344493  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  516  ; KL:  0.002451825  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  517  ; KL:  0.015854316  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  518  ; KL:  0.0025475265  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  519  ; KL:  0.0011838145  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  520  ; KL:  0.0014276053  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  521  ; KL:  0.0041485555  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  522  ; KL:  0.00090428913  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  523  ; KL:  0.0002686375  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  524  ; KL:  0.005202932  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  525  ; KL:  0.00018931596  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  526  ; KL:  0.0013626263  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  527  ; KL:  0.0005558676  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  528  ; KL:  0.013367529  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  529  ; KL:  0.0001239115  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  530  ; KL:  0.00017986029  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  531  ; KL:  0.0027427583  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  532  ; KL:  0.0056118425  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  533  ; KL:  0.0010734263  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  534  ; KL:  0.0005841675  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  535  ; KL:  0.0019283611  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  536  ; KL:  0.0012941231  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  537  ; KL:  0.00027581098  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  538  ; KL:  0.008882139  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  539  ; KL:  0.00042904724  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  540  ; KL:  0.004348468  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  541  ; KL:  0.001727644  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  542  ; KL:  0.0025804616  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  543  ; KL:  0.0009408225  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  544  ; KL:  0.0006692799  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  545  ; KL:  6.320917e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  546  ; KL:  0.0005244931  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  547  ; KL:  0.002633925  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  548  ; KL:  0.0009162229  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  549  ; KL:  0.002278158  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  550  ; KL:  0.0009688911  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  551  ; KL:  0.00022678328  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  552  ; KL:  0.0025477791  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  553  ; KL:  0.0036046915  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  554  ; KL:  0.00023386427  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  555  ; KL:  0.0017817273  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  556  ; KL:  0.00085741334  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  557  ; KL:  0.0006915803  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  558  ; KL:  8.166427e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  559  ; KL:  0.005333858  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  560  ; KL:  0.001791523  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  561  ; KL:  0.0001465614  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  562  ; KL:  0.00070606737  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  563  ; KL:  0.00047770032  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  564  ; KL:  0.007882883  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  565  ; KL:  0.008856987  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  566  ; KL:  0.0003475616  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  567  ; KL:  3.331166e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  568  ; KL:  0.00023972146  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  569  ; KL:  0.007330727  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  570  ; KL:  0.0018515511  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  571  ; KL:  0.008898534  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  572  ; KL:  0.00031841698  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  573  ; KL:  0.0050080554  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  574  ; KL:  0.006172586  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  575  ; KL:  0.002182004  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  576  ; KL:  0.015312998  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  577  ; KL:  0.0027928324  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  578  ; KL:  0.00019486617  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  579  ; KL:  0.0010629015  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  580  ; KL:  0.0007254152  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  581  ; KL:  0.0017292316  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  582  ; KL:  0.0019071652  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  583  ; KL:  0.00022273338  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  584  ; KL:  0.009210522  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  585  ; KL:  0.00027408559  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  586  ; KL:  0.019883852  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  587  ; KL:  0.0018897613  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  588  ; KL:  0.011116186  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  589  ; KL:  0.0004518052  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  590  ; KL:  0.0012605955  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  591  ; KL:  0.005917531  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  592  ; KL:  0.0011705821  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  593  ; KL:  0.0038996625  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  594  ; KL:  0.00062522665  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  595  ; KL:  0.0076721823  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  596  ; KL:  0.001562215  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  597  ; KL:  0.0070289685  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  598  ; KL:  0.018311895  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  599  ; KL:  0.004094352  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  600  ; KL:  0.004231068  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  601  ; KL:  0.0007787975  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  602  ; KL:  0.00042689082  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  603  ; KL:  0.0065165367  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  604  ; KL:  0.0015067294  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  605  ; KL:  0.00094032765  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  606  ; KL:  0.0006311506  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# ...
# Collection
# Tapework
# epoch:  798  ; KL:  0.00016264395  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  799  ; KL:  0.0010273174  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  800  ; KL:  0.001395994  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  801  ; KL:  0.004153318  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  802  ; KL:  0.0003305446  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  803  ; KL:  0.0035277903  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  804  ; KL:  0.010663474  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  805  ; KL:  0.00028604042  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  806  ; KL:  0.0041970415  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  807  ; KL:  0.0063789818  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  808  ; KL:  0.0033964044  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  809  ; KL:  0.00014125837  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  810  ; KL:  0.004359089  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  811  ; KL:  0.003844669  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  812  ; KL:  0.0046831793  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  813  ; KL:  0.0020188068  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  814  ; KL:  0.0050315903  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  815  ; KL:  0.0037024983  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  816  ; KL:  0.006092299  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  817  ; KL:  0.0016476335  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  818  ; KL:  0.002988294  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  819  ; KL:  0.0013229464  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  820  ; KL:  0.0007550989  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  821  ; KL:  0.00068832305  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  822  ; KL:  0.00503012  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  823  ; KL:  0.005235428  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  824  ; KL:  4.865505e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  825  ; KL:  0.0017439339  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  826  ; KL:  0.0018813681  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  827  ; KL:  0.0027391715  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  828  ; KL:  0.0018734896  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  829  ; KL:  1.46620205e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  830  ; KL:  0.0011571818  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  831  ; KL:  0.0021767903  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  832  ; KL:  0.00029697496  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  833  ; KL:  0.0031202028  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  834  ; KL:  0.00017445187  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  835  ; KL:  0.0011275532  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  836  ; KL:  0.0056647123  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  837  ; KL:  0.0012693285  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  838  ; KL:  0.0008146628  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  839  ; KL:  0.0025113004  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  840  ; KL:  0.009986512  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  841  ; KL:  0.019881275  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  842  ; KL:  0.0041057128  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  843  ; KL:  0.0020340802  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  844  ; KL:  0.004554431  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  845  ; KL:  0.00500949  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  846  ; KL:  0.00035643455  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  847  ; KL:  0.007240939  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  848  ; KL:  0.0005092494  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  849  ; KL:  0.0014589553  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  850  ; KL:  0.002903285  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  851  ; KL:  0.0010312244  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  852  ; KL:  0.0024945782  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  853  ; KL:  0.013841556  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  854  ; KL:  0.0039579407  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  855  ; KL:  0.0035123539  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  856  ; KL:  0.0012100792  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  857  ; KL:  0.003490968  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  858  ; KL:  0.00039789887  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  859  ; KL:  0.004138762  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  860  ; KL:  0.0033081167  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  861  ; KL:  0.0011945174  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  862  ; KL:  4.9189457e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  863  ; KL:  0.0007187293  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  864  ; KL:  0.00017050406  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  865  ; KL:  0.0009675275  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  866  ; KL:  0.00053760665  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  867  ; KL:  0.000103687526  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  868  ; KL:  0.0006656093  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  869  ; KL:  0.001010011  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  870  ; KL:  0.0010929956  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  871  ; KL:  0.0047238  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  872  ; KL:  0.011677006  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  873  ; KL:  0.0018310754  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  874  ; KL:  0.0005747827  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  875  ; KL:  0.0012504378  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  876  ; KL:  0.00036826398  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  877  ; KL:  0.0017443299  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  878  ; KL:  0.00061443506  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  879  ; KL:  0.00792285  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  880  ; KL:  0.00035271433  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  881  ; KL:  0.0037794649  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  882  ; KL:  0.0008383074  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  883  ; KL:  0.00036588547  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  884  ; KL:  0.00031755664  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  885  ; KL:  0.009384182  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  886  ; KL:  0.00095684855  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  887  ; KL:  3.198827e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  888  ; KL:  0.0016955407  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  889  ; KL:  0.007043914  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  890  ; KL:  0.00030088986  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  891  ; KL:  0.0028167053  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  892  ; KL:  0.002457327  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  893  ; KL:  0.0049448167  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  894  ; KL:  0.0067236167  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  895  ; KL:  0.0011748243  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  896  ; KL:  0.0008874441  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  897  ; KL:  0.004445478  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  898  ; KL:  0.0042494196  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  899  ; KL:  0.0010875607  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  900  ; KL:  0.0007261848  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  901  ; KL:  0.0071640676  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  902  ; KL:  0.0005844397  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  903  ; KL:  0.00090509624  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  904  ; KL:  0.00030103477  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  905  ; KL:  0.011935919  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  906  ; KL:  0.00097248016  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  907  ; KL:  0.0047335564  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  908  ; KL:  0.0008987602  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  909  ; KL:  0.005739971  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  910  ; KL:  0.020274598  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  911  ; KL:  0.0011309837  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  912  ; KL:  0.0025793847  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  913  ; KL:  0.009587646  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  914  ; KL:  0.0014394219  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  915  ; KL:  0.006594001  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  916  ; KL:  0.00069319713  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  917  ; KL:  0.00718363  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  918  ; KL:  0.000102305174  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  919  ; KL:  0.0023035388  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  920  ; KL:  0.0044070515  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  921  ; KL:  0.00045361777  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  922  ; KL:  0.00091799546  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  923  ; KL:  0.0010890611  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  924  ; KL:  0.00057226507  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  925  ; KL:  0.00078493136  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  926  ; KL:  0.0017841872  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  927  ; KL:  0.0039804657  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  928  ; KL:  0.0010012606  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  929  ; KL:  0.0021177244  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  930  ; KL:  0.00032563673  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  931  ; KL:  0.00056761265  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  932  ; KL:  0.00011526797  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  933  ; KL:  0.00019163026  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  934  ; KL:  0.0028985417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  935  ; KL:  0.00028435932  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  936  ; KL:  0.0004777669  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  937  ; KL:  0.008026552  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  938  ; KL:  0.012229654  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  939  ; KL:  0.005329301  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  940  ; KL:  0.011322764  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  941  ; KL:  0.00026626396  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  942  ; KL:  0.00025705234  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  943  ; KL:  0.0014772337  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  944  ; KL:  0.00212135  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  945  ; KL:  1.6217167e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  946  ; KL:  0.0049490635  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  947  ; KL:  0.0046384805  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  948  ; KL:  0.0077421544  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  949  ; KL:  0.00073201756  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  950  ; KL:  0.0005072423  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  951  ; KL:  0.0006062652  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  952  ; KL:  0.007846353  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  953  ; KL:  0.0055631404  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  954  ; KL:  0.009954732  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  955  ; KL:  0.0011277801  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  956  ; KL:  0.0008443602  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  957  ; KL:  0.0014375307  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  958  ; KL:  0.0016102417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  959  ; KL:  0.0016667525  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  960  ; KL:  0.0005490634  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  961  ; KL:  0.00064230093  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  962  ; KL:  0.000107939566  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  963  ; KL:  0.004774276  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  964  ; KL:  0.0069916523  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  965  ; KL:  0.0023521013  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  966  ; KL:  0.00012632852  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  967  ; KL:  0.0051595983  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  968  ; KL:  0.00097128033  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  969  ; KL:  0.00030035165  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  970  ; KL:  0.0008652583  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  971  ; KL:  0.0013650295  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  972  ; KL:  0.003949277  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  973  ; KL:  0.0021930484  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  974  ; KL:  0.0040203566  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  975  ; KL:  0.0012629861  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  976  ; KL:  0.00058546633  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  977  ; KL:  0.00026494887  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  978  ; KL:  0.0055682613  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  979  ; KL:  0.0007140201  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  980  ; KL:  0.0009652711  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  981  ; KL:  0.003980212  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  982  ; KL:  0.0003263688  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  983  ; KL:  0.0005588993  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  984  ; KL:  0.0002770828  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  985  ; KL:  0.0017804599  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  986  ; KL:  0.0013730209  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  987  ; KL:  0.0009095357  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  988  ; KL:  0.00075985346  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  989  ; KL:  0.0041075763  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  990  ; KL:  0.0011135641  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  991  ; KL:  8.230583e-05  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  992  ; KL:  0.0012196213  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  993  ; KL:  0.00200171  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  994  ; KL:  0.00125707  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  995  ; KL:  0.0011256733  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  996  ; KL:  0.0015134768  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  997  ; KL:  0.008840725  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  998  ; KL:  0.001801543  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  999  ; KL:  0.0037285388  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework

# %%
test_env = gym.make('CartPole-v1', render_mode='human')
#test_env = gym.make('CartPole-v1', render_mode='human')
obs, inf = test_env.reset()

# %%
obs, inf = test_env.reset()

# %%
for i in range(1000):
    qs = pi(tf.expand_dims(obs, 0))
    act = [np.argmax(subspace) for subspace in qs[0]]
    obs, reward, terminated, _, _ = test_env.step(act[0])
    if(terminated):
        obs, _ = test_env.reset()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
