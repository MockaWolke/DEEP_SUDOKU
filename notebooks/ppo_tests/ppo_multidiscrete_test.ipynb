# %%
from deepsudoku import REPO_PATH, DIFFICULTIES
import os
os.chdir(REPO_PATH)

import tensorflow as tf
import numpy as np
from deepsudoku.reinforcement_learning.ppo import *

import gymnasium as gym
from deepsudoku.verify_sudoku import *
# Out:
# 2023-08-25 19:54:20.218233: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-25 19:54:20.250260: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-25 19:54:20.251288: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-25 19:54:21.056885: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Sudoku Environment avaible at gymnasium as 'Sudoku-v0'.

# %%
import random

class PPO_MultiDiscrete_Cartpole_Wrapper:
    def __init__(self, NUM_ENVS, **env_kwargs):
        self.num_envs = NUM_ENVS
        # We use vectorized environments (Implementation Detail 1)
        self.envs = envs = gym.vector.make('CartPole-v1', num_envs=NUM_ENVS)
        self.current_state, _ = self.envs.reset()

    def sample(self, model):
        old_observation = self.current_state
        q_values = model(self.current_state) #get q values for current state
        # Q_values are logits, we convert them to a categorical distribution to sample
        # but first we mask out invalid actions
        # ...
        # masked_logits
        masked_logits = q_values

        # Implementing Multi-Discrete Action spaces:
        # masked_logits = [environments][action-spaces][logprobs]
        # We need to sample for each environment from all action-spaces
        # NOTE: This assumes that all action-spaces look like [0,1,2,3,...]
        # In particular, for the sudoku case, the third action space represents the number we want to fill in
        # This number will be one less than the actual digit that gets filled in
        # This is accounted for and implemented like this in our custom environment
        
        #categoricals = np.array([
        #            [tfp.distributions.Categorical(logits=action_space) for action_space in environment]
        #            for environment in masked_logits
        #         ])
        #act_and_logprob = np.array([[action_space.experimental_sample_and_log_prob() for action_space in environment] for environment in categoricals])
        #action = act_and_logprob[..., 0].astype(np.int32)
        #logprobs = np.sum(act_and_logprob[..., 1], axis=-1).astype(np.float32)

        probs = tf.nn.softmax(masked_logits).numpy()
        action = np.array([[np.random.choice(np.arange(len(action_space)),p=action_space) for action_space in environment] for environment in probs])
        logprob = tf.cast(tf.reduce_sum(tf.math.log(tf.gather(probs, action, batch_dims=2)), axis=-1), np.float32).numpy()

        new_observation, reward, terminated, _, _ = self.envs.step(action[:,0])

        self.current_state = new_observation #update current state after environment did step
        return (old_observation, action, reward, new_observation, terminated, logprob)
    
    def collect_trajectories(self, model, length):
        old_obs, act, rew, new_obs, term, log_probs = self.sample(model)
        data = {"observations": np.expand_dims(old_obs, axis=1), 
                "actions": np.expand_dims(act, axis=1), 
                "rewards": rew, 
                "terminateds": term,
                "log_prob": log_probs}
        for i in range(length-1):
            old_obs, act, rew, new_obs, term, log_probs = self.sample(model)
            data["observations"] = np.column_stack((data["observations"], np.expand_dims(old_obs, axis=1)))
            data["actions"] = np.column_stack((data["actions"], np.expand_dims(act, axis=1)))
            data["rewards"] = np.column_stack((data["rewards"], rew))
            data["terminateds"] = np.column_stack((data["terminateds"], term))
            data["log_prob"] = np.column_stack((data["log_prob"], log_probs))
        return data, new_obs

# %%
envs = PPO_MultiDiscrete_Cartpole_Wrapper(5)

# %%
# Create models

# Implementation Detail 2: Orthogonal Initialization of hidden weights and constant initialization of biases and output weights
# Biases seem to be 0 by default in Keras
hidden_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=np.sqrt(2))
pol_out_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=0.01)
val_out_ortho_init = lambda: tf.keras.initializers.Orthogonal(gain=1)

def create_policy_model():
    inputs = tf.keras.Input(shape=(4))
    x = tf.keras.layers.Flatten()(inputs)
    x = tf.keras.layers.Dense(128, activation="tanh", kernel_initializer=hidden_ortho_init())(x)
    x = tf.keras.layers.Dense(128, activation="tanh", kernel_initializer=hidden_ortho_init())(x)
    x = tf.keras.layers.Dense(2, activation="linear", kernel_initializer=pol_out_ortho_init())(x)
    outputs = tf.keras.layers.Reshape((1,2))(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="pi")
    return model

def create_value_function_model():
    inputs = tf.keras.Input(shape=(4))
    x = tf.keras.layers.Flatten()(inputs)
    x = tf.keras.layers.Dense(32, activation="relu", kernel_initializer=hidden_ortho_init())(x)
    #x = tf.keras.layers.Dense(32, activation="relu", kernel_initializer=hidden_ortho_init())(x)
    outputs = tf.keras.layers.Dense(1, activation="linear", kernel_initializer=val_out_ortho_init())(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="V")
    return model

# %%
pi, V = PPO(envs, create_policy_model(), create_value_function_model(), TRAIN_EPOCHS = 1000, LEARNING_RATE_DECAY_PER_EPOCH = 0, LEARNING_RATE_START=0.001)
# Out:
# epoch:  0  ; KL:  0  ; LR:  0.001  ; MR:  0
# Collection
# Tapework
# epoch:  1  ; KL:  0.2956854  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  2  ; KL:  0.29866037  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  3  ; KL:  0.26311696  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  4  ; KL:  0.22260241  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  5  ; KL:  0.2732033  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  6  ; KL:  0.20497116  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  7  ; KL:  0.16834933  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  8  ; KL:  0.09911118  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  9  ; KL:  0.027768832  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  10  ; KL:  0.00574699  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  11  ; KL:  0.011989912  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  12  ; KL:  0.01455845  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  13  ; KL:  0.0077823484  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  14  ; KL:  0.009258436  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  15  ; KL:  0.0073166625  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  16  ; KL:  0.007338134  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  17  ; KL:  0.0036817095  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  18  ; KL:  0.009425007  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  19  ; KL:  0.01789751  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  20  ; KL:  0.020282898  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  21  ; KL:  0.00744364  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  22  ; KL:  0.010908547  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  23  ; KL:  0.016563276  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  24  ; KL:  0.009462108  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  25  ; KL:  0.007741952  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  26  ; KL:  0.019263776  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  27  ; KL:  0.011867948  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  28  ; KL:  0.00811237  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  29  ; KL:  0.0054952973  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  30  ; KL:  0.003182267  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  31  ; KL:  0.004242152  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  32  ; KL:  0.0048204483  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  33  ; KL:  0.008618065  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  34  ; KL:  0.010481818  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  35  ; KL:  0.013526213  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  36  ; KL:  0.012833678  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  37  ; KL:  0.019311782  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  38  ; KL:  0.00832892  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  39  ; KL:  0.0077765267  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  40  ; KL:  0.009266539  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  41  ; KL:  0.0047417963  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  42  ; KL:  0.0101593975  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  43  ; KL:  0.012745255  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  44  ; KL:  0.012444977  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  45  ; KL:  0.011505312  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  46  ; KL:  0.023097547  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  47  ; KL:  0.02204624  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  48  ; KL:  0.009178909  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  49  ; KL:  0.010062545  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  50  ; KL:  0.008406095  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  51  ; KL:  0.005290045  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  52  ; KL:  0.0069518327  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  53  ; KL:  0.010171163  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  54  ; KL:  0.0082920585  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  55  ; KL:  0.018512327  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  56  ; KL:  0.019198932  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  57  ; KL:  0.022551823  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  58  ; KL:  0.013762176  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  59  ; KL:  0.01744009  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  60  ; KL:  0.02086566  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  61  ; KL:  0.0178738  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  62  ; KL:  0.023471484  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  63  ; KL:  0.024287343  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  64  ; KL:  0.02317055  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  65  ; KL:  0.016424138  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  66  ; KL:  0.013769079  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  67  ; KL:  0.012029322  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  68  ; KL:  0.012647942  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  69  ; KL:  0.023464266  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  70  ; KL:  0.026757166  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  71  ; KL:  0.018936092  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  72  ; KL:  0.04920182  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  73  ; KL:  0.035851788  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  74  ; KL:  0.031460717  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  75  ; KL:  0.025596904  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  76  ; KL:  0.021970535  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  77  ; KL:  0.020603612  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  78  ; KL:  0.034449726  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  79  ; KL:  0.03222507  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  80  ; KL:  0.017165203  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  81  ; KL:  0.020883542  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  82  ; KL:  0.014821135  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  83  ; KL:  0.016621642  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  84  ; KL:  0.029197583  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  85  ; KL:  0.042792335  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  86  ; KL:  0.049092233  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  87  ; KL:  0.032406684  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  88  ; KL:  0.058175776  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  89  ; KL:  0.03880199  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  90  ; KL:  0.03829541  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  91  ; KL:  0.024932565  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  92  ; KL:  0.020592108  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  93  ; KL:  0.022560136  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  94  ; KL:  0.022087846  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  95  ; KL:  0.020109663  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  96  ; KL:  0.028179966  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  97  ; KL:  0.023513706  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  98  ; KL:  0.02459367  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  99  ; KL:  0.020159803  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  100  ; KL:  0.035078853  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  101  ; KL:  0.028898096  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  102  ; KL:  0.020993836  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  103  ; KL:  0.017583814  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  104  ; KL:  0.024671268  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  105  ; KL:  0.021400267  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  106  ; KL:  0.03585101  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  107  ; KL:  0.018094374  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  108  ; KL:  0.03553654  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  109  ; KL:  0.031329304  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  110  ; KL:  0.033763647  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  111  ; KL:  0.015761556  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  112  ; KL:  0.014685933  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  113  ; KL:  0.017188821  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  114  ; KL:  0.017328043  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  115  ; KL:  0.019397186  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  116  ; KL:  0.04517334  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  117  ; KL:  0.024891518  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  118  ; KL:  0.04269568  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  119  ; KL:  0.028456736  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  120  ; KL:  0.020632021  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  121  ; KL:  0.030391032  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  122  ; KL:  0.021769982  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  123  ; KL:  0.03809112  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  124  ; KL:  0.019257687  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  125  ; KL:  0.03297769  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  126  ; KL:  0.019369274  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  127  ; KL:  0.019815149  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  128  ; KL:  0.028720763  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  129  ; KL:  0.0118708145  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  130  ; KL:  0.050334666  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  131  ; KL:  0.021667805  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  132  ; KL:  0.02420362  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  133  ; KL:  0.038115107  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  134  ; KL:  0.04784778  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  135  ; KL:  0.030159464  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  136  ; KL:  0.028064042  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  137  ; KL:  0.04699669  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  138  ; KL:  0.024941644  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  139  ; KL:  0.016851455  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  140  ; KL:  0.02792302  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  141  ; KL:  0.034875423  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  142  ; KL:  0.023426978  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  143  ; KL:  0.018880323  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  144  ; KL:  0.022087358  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  145  ; KL:  0.018765932  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  146  ; KL:  0.03081575  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  147  ; KL:  0.044696428  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  148  ; KL:  0.023353761  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  149  ; KL:  0.010823771  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  150  ; KL:  0.024244152  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  151  ; KL:  0.023008902  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  152  ; KL:  0.056522436  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  153  ; KL:  0.06626946  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  154  ; KL:  0.026809582  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  155  ; KL:  0.03979163  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  156  ; KL:  0.028412983  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  157  ; KL:  0.027866572  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  158  ; KL:  0.027473243  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  159  ; KL:  0.049186006  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  160  ; KL:  0.04252235  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  161  ; KL:  0.06626724  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  162  ; KL:  0.0791411  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  163  ; KL:  0.024021069  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  164  ; KL:  0.09951916  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  165  ; KL:  0.06375104  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  166  ; KL:  0.03820404  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  167  ; KL:  0.021475257  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  168  ; KL:  0.044920567  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  169  ; KL:  0.07230014  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  170  ; KL:  0.05223974  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  171  ; KL:  0.026395334  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  172  ; KL:  0.073650435  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  173  ; KL:  0.04585169  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  174  ; KL:  0.03524617  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  175  ; KL:  0.032298807  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  176  ; KL:  0.07434671  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  177  ; KL:  0.06687252  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  178  ; KL:  0.050481707  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  179  ; KL:  0.10037162  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  180  ; KL:  0.06897  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  181  ; KL:  0.042663787  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  182  ; KL:  0.046363257  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  183  ; KL:  0.066099264  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  184  ; KL:  0.04163388  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  185  ; KL:  0.05727438  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  186  ; KL:  0.018270502  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  187  ; KL:  0.046083592  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  188  ; KL:  0.055366367  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  189  ; KL:  0.03425965  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  190  ; KL:  0.024379743  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  191  ; KL:  0.07412079  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  192  ; KL:  0.04049724  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  193  ; KL:  0.038614195  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  194  ; KL:  0.04663749  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  195  ; KL:  0.048289668  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  196  ; KL:  0.05592717  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  197  ; KL:  0.09267257  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  198  ; KL:  0.019285545  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  199  ; KL:  0.12475554  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  200  ; KL:  0.043796927  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  201  ; KL:  0.034489334  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  202  ; KL:  0.030789874  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  203  ; KL:  0.091968864  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  204  ; KL:  0.08204995  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  205  ; KL:  0.031346954  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  206  ; KL:  0.057456307  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  207  ; KL:  0.06712423  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  208  ; KL:  0.010059443  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  209  ; KL:  0.059195537  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  210  ; KL:  0.048276424  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  211  ; KL:  0.048159868  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  212  ; KL:  0.024187619  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  213  ; KL:  0.037500255  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  214  ; KL:  0.041640546  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  215  ; KL:  0.03477547  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  216  ; KL:  0.041474584  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  217  ; KL:  0.044012263  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  218  ; KL:  0.048478283  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  219  ; KL:  0.056937538  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  220  ; KL:  0.06917647  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  221  ; KL:  0.018078214  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  222  ; KL:  0.084386975  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  223  ; KL:  0.06634742  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  224  ; KL:  0.035451867  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  225  ; KL:  0.073958404  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  226  ; KL:  0.020780375  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  227  ; KL:  0.055131067  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  228  ; KL:  0.05894354  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  229  ; KL:  0.08436658  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  230  ; KL:  0.071359284  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  231  ; KL:  0.04444183  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  232  ; KL:  0.054213338  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  233  ; KL:  0.07401798  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  234  ; KL:  0.024789372  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  235  ; KL:  0.044761457  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  236  ; KL:  0.049468227  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  237  ; KL:  0.03121649  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  238  ; KL:  0.06003585  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  239  ; KL:  0.024565186  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  240  ; KL:  0.02297855  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  241  ; KL:  0.035679005  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  242  ; KL:  0.05963786  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  243  ; KL:  0.06751693  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  244  ; KL:  0.050046932  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  245  ; KL:  0.045894336  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  246  ; KL:  0.07591581  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  247  ; KL:  0.07067818  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  248  ; KL:  0.080127425  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  249  ; KL:  0.11532634  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  250  ; KL:  0.10023224  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  251  ; KL:  0.02256311  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  252  ; KL:  0.093166284  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  253  ; KL:  0.054956097  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  254  ; KL:  0.048333853  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  255  ; KL:  0.11851174  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  256  ; KL:  0.048915416  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  257  ; KL:  0.08762566  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  258  ; KL:  0.10135974  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  259  ; KL:  0.04799658  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  260  ; KL:  0.057671495  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  261  ; KL:  0.03804468  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  262  ; KL:  0.074142784  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  263  ; KL:  0.0711203  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  264  ; KL:  0.08261845  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  265  ; KL:  0.06202502  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  266  ; KL:  0.11314866  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  267  ; KL:  0.100686364  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  268  ; KL:  0.048556823  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  269  ; KL:  0.052060377  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  270  ; KL:  0.045323424  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  271  ; KL:  0.05156465  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  272  ; KL:  0.04862916  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  273  ; KL:  0.0846391  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  274  ; KL:  0.03969841  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  275  ; KL:  0.04834476  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  276  ; KL:  0.045767292  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  277  ; KL:  0.039163243  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  278  ; KL:  0.033753544  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  279  ; KL:  0.0477497  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  280  ; KL:  0.03661326  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  281  ; KL:  0.029394  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  282  ; KL:  0.05688434  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  283  ; KL:  0.05758478  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  284  ; KL:  0.04369244  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  285  ; KL:  0.039081514  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  286  ; KL:  0.03969515  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  287  ; KL:  0.036234614  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  288  ; KL:  0.03117044  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  289  ; KL:  0.03778568  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  290  ; KL:  0.049688894  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  291  ; KL:  0.020050857  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  292  ; KL:  0.026100108  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  293  ; KL:  0.03983697  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  294  ; KL:  0.013605531  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  295  ; KL:  0.019580068  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  296  ; KL:  0.03425574  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  297  ; KL:  0.030163344  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  298  ; KL:  0.026191687  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  299  ; KL:  0.025632787  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  300  ; KL:  0.02358566  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  301  ; KL:  0.075678565  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  302  ; KL:  0.055146404  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  303  ; KL:  0.060949933  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  304  ; KL:  0.08807134  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  305  ; KL:  0.03196309  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  306  ; KL:  0.04809164  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  307  ; KL:  0.01729801  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  308  ; KL:  0.0579001  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  309  ; KL:  0.03322482  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  310  ; KL:  0.035551958  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  311  ; KL:  0.072314896  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  312  ; KL:  0.08165337  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  313  ; KL:  0.04832824  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  314  ; KL:  0.08000833  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  315  ; KL:  0.052940514  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  316  ; KL:  0.108869135  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  317  ; KL:  0.04441002  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  318  ; KL:  0.05327721  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  319  ; KL:  0.07681814  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  320  ; KL:  0.07677742  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  321  ; KL:  0.06476463  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  322  ; KL:  0.07495856  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  323  ; KL:  0.06556483  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  324  ; KL:  0.04110998  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  325  ; KL:  0.13422519  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  326  ; KL:  0.08392297  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  327  ; KL:  0.074978225  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  328  ; KL:  0.12023953  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  329  ; KL:  0.09434335  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  330  ; KL:  0.11508016  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  331  ; KL:  0.045291554  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  332  ; KL:  0.15025279  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  333  ; KL:  0.08890178  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  334  ; KL:  0.09148817  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  335  ; KL:  0.15104969  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  336  ; KL:  0.05429179  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  337  ; KL:  0.06910366  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  338  ; KL:  0.05822915  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  339  ; KL:  0.070092164  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  340  ; KL:  0.09142627  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  341  ; KL:  0.118601665  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  342  ; KL:  0.06855711  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  343  ; KL:  0.10663773  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  344  ; KL:  0.07025559  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  345  ; KL:  0.070258886  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  346  ; KL:  0.051226173  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  347  ; KL:  0.040964536  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  348  ; KL:  0.06866541  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  349  ; KL:  0.10647526  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  350  ; KL:  0.078780696  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  351  ; KL:  0.03813112  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  352  ; KL:  0.04723182  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  353  ; KL:  0.034969322  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  354  ; KL:  0.08491147  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  355  ; KL:  0.09873566  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  356  ; KL:  0.06686951  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  357  ; KL:  0.06745824  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  358  ; KL:  0.082046576  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  359  ; KL:  0.06578479  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  360  ; KL:  0.066111125  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  361  ; KL:  0.032834645  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  362  ; KL:  0.046374526  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  363  ; KL:  0.045353476  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  364  ; KL:  0.062927686  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  365  ; KL:  0.06106997  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  366  ; KL:  0.0575642  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  367  ; KL:  0.08779921  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  368  ; KL:  0.068080686  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  369  ; KL:  0.073483445  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  370  ; KL:  0.17412089  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  371  ; KL:  0.11941188  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  372  ; KL:  0.08104243  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  373  ; KL:  0.10680641  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  374  ; KL:  0.18525214  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  375  ; KL:  0.24366137  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  376  ; KL:  0.17964807  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  377  ; KL:  0.1155693  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  378  ; KL:  0.11851266  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  379  ; KL:  0.096521355  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  380  ; KL:  0.16003352  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  381  ; KL:  0.2057445  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  382  ; KL:  0.15547538  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  383  ; KL:  0.12439984  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  384  ; KL:  0.11014777  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  385  ; KL:  0.09023157  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  386  ; KL:  0.08375778  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  387  ; KL:  0.10401806  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  388  ; KL:  0.1368647  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  389  ; KL:  0.07217826  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  390  ; KL:  0.0831334  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  391  ; KL:  0.1031183  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  392  ; KL:  0.045658365  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  393  ; KL:  0.057104364  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  394  ; KL:  0.08079868  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  395  ; KL:  0.07988684  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  396  ; KL:  0.10572973  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  397  ; KL:  0.0673454  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  398  ; KL:  0.090777464  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  399  ; KL:  0.060242668  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  400  ; KL:  0.06047193  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  401  ; KL:  0.08106049  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  402  ; KL:  0.095755726  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  403  ; KL:  0.05352518  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  404  ; KL:  0.07219509  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  405  ; KL:  0.10411473  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  406  ; KL:  0.1252927  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  407  ; KL:  0.07960033  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  408  ; KL:  0.090769924  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  409  ; KL:  0.06869251  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  410  ; KL:  0.09733292  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  411  ; KL:  0.07381744  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  412  ; KL:  0.07692804  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  413  ; KL:  0.10571511  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  414  ; KL:  0.038147185  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  415  ; KL:  0.06855064  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  416  ; KL:  0.07742818  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  417  ; KL:  0.050173838  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  418  ; KL:  0.06663591  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  419  ; KL:  0.06261045  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  420  ; KL:  0.029508678  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  421  ; KL:  0.06470779  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  422  ; KL:  0.14065501  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  423  ; KL:  0.06787226  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  424  ; KL:  0.082917035  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  425  ; KL:  0.10783645  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  426  ; KL:  0.071954995  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  427  ; KL:  0.073167324  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  428  ; KL:  0.04555122  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  429  ; KL:  0.06259992  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  430  ; KL:  0.06788217  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  431  ; KL:  0.07228133  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  432  ; KL:  0.074315935  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  433  ; KL:  0.086972624  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  434  ; KL:  0.070352755  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  435  ; KL:  0.14070211  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  436  ; KL:  0.110972255  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  437  ; KL:  0.0588623  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  438  ; KL:  0.13180417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  439  ; KL:  0.062026817  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  440  ; KL:  0.06555687  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  441  ; KL:  0.0881362  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  442  ; KL:  0.045714866  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  443  ; KL:  0.042740963  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  444  ; KL:  0.021260586  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  445  ; KL:  0.02846009  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  446  ; KL:  0.03326854  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  447  ; KL:  0.0430631  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  448  ; KL:  0.04261891  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  449  ; KL:  0.064821444  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  450  ; KL:  0.062064685  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  451  ; KL:  0.10579414  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  452  ; KL:  0.096342236  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  453  ; KL:  0.08702918  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  454  ; KL:  0.06500437  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  455  ; KL:  0.069626525  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  456  ; KL:  0.14185853  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  457  ; KL:  0.055568844  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  458  ; KL:  0.0807712  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  459  ; KL:  0.02213416  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  460  ; KL:  0.11262468  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  461  ; KL:  0.11942136  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  462  ; KL:  0.06325972  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  463  ; KL:  0.11621714  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  464  ; KL:  0.10286729  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  465  ; KL:  0.14196451  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  466  ; KL:  0.17663917  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  467  ; KL:  0.11758551  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  468  ; KL:  0.13863485  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  469  ; KL:  0.11249912  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  470  ; KL:  0.09745018  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  471  ; KL:  0.06260257  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  472  ; KL:  0.050131653  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  473  ; KL:  0.05772845  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  474  ; KL:  0.056305707  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  475  ; KL:  0.06977984  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  476  ; KL:  0.078786545  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  477  ; KL:  0.026056565  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  478  ; KL:  0.03161436  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  479  ; KL:  0.049365904  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  480  ; KL:  0.041739766  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  481  ; KL:  0.07241128  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  482  ; KL:  0.056630734  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  483  ; KL:  0.06632051  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  484  ; KL:  0.064838484  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  485  ; KL:  0.05344237  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  486  ; KL:  0.062544696  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  487  ; KL:  0.04330848  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  488  ; KL:  0.04572555  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  489  ; KL:  0.04394588  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  490  ; KL:  0.08093027  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  491  ; KL:  0.031009173  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  492  ; KL:  0.062161174  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  493  ; KL:  0.06602403  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  494  ; KL:  0.056184813  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  495  ; KL:  0.007749498  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  496  ; KL:  0.03586458  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  497  ; KL:  0.02206508  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  498  ; KL:  0.044196162  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  499  ; KL:  0.05857278  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  500  ; KL:  0.04624477  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  501  ; KL:  0.07319279  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  502  ; KL:  0.054108966  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  503  ; KL:  0.038169887  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  504  ; KL:  0.046964582  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  505  ; KL:  0.06453394  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  506  ; KL:  0.0386545  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  507  ; KL:  0.029792832  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  508  ; KL:  0.05397222  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  509  ; KL:  0.06256538  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  510  ; KL:  0.029007683  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  511  ; KL:  0.033157814  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  512  ; KL:  0.06291987  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  513  ; KL:  0.04817038  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  514  ; KL:  0.036395576  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  515  ; KL:  0.06368349  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  516  ; KL:  0.089617826  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  517  ; KL:  0.07337251  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  518  ; KL:  0.054520957  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  519  ; KL:  0.04500717  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  520  ; KL:  0.0499783  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  521  ; KL:  0.06686377  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  522  ; KL:  0.067706436  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  523  ; KL:  0.0684601  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  524  ; KL:  0.054964237  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  525  ; KL:  0.028372297  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  526  ; KL:  0.054826852  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  527  ; KL:  0.09130138  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  528  ; KL:  0.043999482  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  529  ; KL:  0.044490755  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  530  ; KL:  0.03719007  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  531  ; KL:  0.021073498  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  532  ; KL:  0.032870933  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  533  ; KL:  0.06529502  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  534  ; KL:  0.0564518  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  535  ; KL:  0.051398728  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  536  ; KL:  0.08757034  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  537  ; KL:  0.048874874  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  538  ; KL:  0.037404623  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  539  ; KL:  0.06930291  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  540  ; KL:  0.049678076  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  541  ; KL:  0.02203897  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  542  ; KL:  0.043985404  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  543  ; KL:  0.010998419  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  544  ; KL:  0.073525585  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  545  ; KL:  0.055501282  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  546  ; KL:  0.039429218  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  547  ; KL:  0.08826537  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  548  ; KL:  0.049691133  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  549  ; KL:  0.059327796  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  550  ; KL:  0.06083705  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  551  ; KL:  0.06880046  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  552  ; KL:  0.049679577  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  553  ; KL:  0.06174086  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  554  ; KL:  0.08123535  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  555  ; KL:  0.08378875  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  556  ; KL:  0.076777  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  557  ; KL:  0.11527655  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  558  ; KL:  0.052264117  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  559  ; KL:  0.034544226  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  560  ; KL:  0.048324373  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  561  ; KL:  0.035040192  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  562  ; KL:  0.021282254  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  563  ; KL:  0.05110944  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  564  ; KL:  0.029523479  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  565  ; KL:  0.03313734  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  566  ; KL:  0.054039415  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  567  ; KL:  0.05063783  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  568  ; KL:  0.08974075  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  569  ; KL:  0.09553668  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  570  ; KL:  0.09473159  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  571  ; KL:  0.07117044  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  572  ; KL:  0.096698545  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  573  ; KL:  0.102219306  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  574  ; KL:  0.04499109  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  575  ; KL:  0.04402619  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  576  ; KL:  0.037963282  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  577  ; KL:  0.05689087  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  578  ; KL:  0.07772232  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  579  ; KL:  0.122584626  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  580  ; KL:  0.110705  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  581  ; KL:  0.119857065  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  582  ; KL:  0.06618284  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  583  ; KL:  0.06448487  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  584  ; KL:  0.06955076  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  585  ; KL:  0.05060694  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  586  ; KL:  0.06072729  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  587  ; KL:  0.06970294  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  588  ; KL:  0.0958505  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  589  ; KL:  0.049410123  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  590  ; KL:  0.035719473  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  591  ; KL:  0.008367892  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  592  ; KL:  0.074049115  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  593  ; KL:  0.06337421  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  594  ; KL:  0.10478225  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  595  ; KL:  0.16827096  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  596  ; KL:  0.10320965  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  597  ; KL:  0.16707548  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  598  ; KL:  0.12449036  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  599  ; KL:  0.033261232  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  600  ; KL:  0.03796409  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  601  ; KL:  0.04000857  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  602  ; KL:  0.04949199  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  603  ; KL:  0.08229172  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  604  ; KL:  0.13505343  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  605  ; KL:  0.11303529  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  606  ; KL:  0.1129748  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  607  ; KL:  0.17135558  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  608  ; KL:  0.08753805  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  609  ; KL:  0.06334814  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  610  ; KL:  0.036794316  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  611  ; KL:  0.023643168  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  612  ; KL:  0.06428543  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  613  ; KL:  0.051260047  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  614  ; KL:  0.040948253  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  615  ; KL:  0.062390182  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  616  ; KL:  0.044828266  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  617  ; KL:  0.03513632  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  618  ; KL:  0.04255153  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  619  ; KL:  0.03549993  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  620  ; KL:  0.049209833  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# ...
# Tapework
# epoch:  794  ; KL:  0.06206024  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  795  ; KL:  0.059111357  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  796  ; KL:  0.06454309  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  797  ; KL:  0.04571484  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  798  ; KL:  0.032672416  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  799  ; KL:  0.032757953  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  800  ; KL:  0.041175716  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  801  ; KL:  0.032653682  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  802  ; KL:  0.035100043  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  803  ; KL:  0.028146142  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  804  ; KL:  0.043818936  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  805  ; KL:  0.04877985  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  806  ; KL:  0.05024371  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  807  ; KL:  0.04967636  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  808  ; KL:  0.05823843  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  809  ; KL:  0.034790322  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  810  ; KL:  0.029603971  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  811  ; KL:  0.039424237  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  812  ; KL:  0.036633242  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  813  ; KL:  0.056464683  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  814  ; KL:  0.0626764  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  815  ; KL:  0.03114751  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  816  ; KL:  0.068558  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  817  ; KL:  0.057196125  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  818  ; KL:  0.026097711  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  819  ; KL:  0.064199135  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  820  ; KL:  0.052011564  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  821  ; KL:  0.066638306  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  822  ; KL:  0.062189564  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  823  ; KL:  0.07568801  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  824  ; KL:  0.065420255  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  825  ; KL:  0.051385097  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  826  ; KL:  0.06489619  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  827  ; KL:  0.053753264  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  828  ; KL:  0.050782055  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  829  ; KL:  0.042593468  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  830  ; KL:  0.031650513  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  831  ; KL:  0.03718366  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  832  ; KL:  0.021434769  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  833  ; KL:  0.027953459  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  834  ; KL:  0.04304694  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  835  ; KL:  0.026624331  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  836  ; KL:  0.020981977  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  837  ; KL:  0.041295554  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  838  ; KL:  0.045688562  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  839  ; KL:  0.026182972  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  840  ; KL:  0.031356424  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  841  ; KL:  0.048267413  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  842  ; KL:  0.060126796  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  843  ; KL:  0.041639213  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  844  ; KL:  0.03500111  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  845  ; KL:  0.03977154  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  846  ; KL:  0.04768832  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  847  ; KL:  0.06288383  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  848  ; KL:  0.055355646  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  849  ; KL:  0.05565593  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  850  ; KL:  0.0280527  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  851  ; KL:  0.06780694  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  852  ; KL:  0.051270433  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  853  ; KL:  0.038925756  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  854  ; KL:  0.043579213  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  855  ; KL:  0.06837048  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  856  ; KL:  0.051992968  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  857  ; KL:  0.038970478  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  858  ; KL:  0.04771915  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  859  ; KL:  0.03736237  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  860  ; KL:  0.019397225  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  861  ; KL:  0.027903747  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  862  ; KL:  0.029905787  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  863  ; KL:  0.010821371  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  864  ; KL:  0.03490342  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  865  ; KL:  0.055770386  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  866  ; KL:  0.045975015  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  867  ; KL:  0.039885744  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  868  ; KL:  0.038557157  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  869  ; KL:  0.018752906  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  870  ; KL:  0.055877715  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  871  ; KL:  0.07337223  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  872  ; KL:  0.08582914  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  873  ; KL:  0.14132638  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  874  ; KL:  0.109098725  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  875  ; KL:  0.075137466  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  876  ; KL:  0.06640268  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  877  ; KL:  0.10071386  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  878  ; KL:  0.068764806  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  879  ; KL:  0.02838607  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  880  ; KL:  0.0580565  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  881  ; KL:  0.013281621  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  882  ; KL:  0.025412904  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  883  ; KL:  0.021590743  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  884  ; KL:  0.053576242  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  885  ; KL:  0.10083692  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  886  ; KL:  0.099249594  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  887  ; KL:  0.0366512  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  888  ; KL:  0.028573966  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  889  ; KL:  0.031886004  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  890  ; KL:  0.036935236  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  891  ; KL:  0.0097038895  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  892  ; KL:  0.025565328  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  893  ; KL:  0.015472417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  894  ; KL:  0.028415054  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  895  ; KL:  0.017003605  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  896  ; KL:  0.011174803  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  897  ; KL:  0.008796465  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  898  ; KL:  0.024258317  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  899  ; KL:  0.011821711  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  900  ; KL:  0.009249848  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  901  ; KL:  0.01334234  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  902  ; KL:  0.070510715  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  903  ; KL:  0.08676433  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  904  ; KL:  0.04243026  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  905  ; KL:  0.08018047  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  906  ; KL:  0.06964187  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  907  ; KL:  0.03588063  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  908  ; KL:  0.036824357  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  909  ; KL:  0.040089168  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  910  ; KL:  0.05554518  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  911  ; KL:  0.038890883  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  912  ; KL:  0.03508384  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  913  ; KL:  0.010738739  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  914  ; KL:  0.053115442  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  915  ; KL:  0.06837164  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  916  ; KL:  0.051009007  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  917  ; KL:  0.058408123  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  918  ; KL:  0.074492395  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  919  ; KL:  0.06391268  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  920  ; KL:  0.06272433  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  921  ; KL:  0.054313123  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  922  ; KL:  0.053553242  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  923  ; KL:  0.056525663  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  924  ; KL:  0.06663861  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  925  ; KL:  0.049089335  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  926  ; KL:  0.07466745  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  927  ; KL:  0.064807855  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  928  ; KL:  0.06292129  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  929  ; KL:  0.06884539  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  930  ; KL:  0.053518385  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  931  ; KL:  0.052349277  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  932  ; KL:  0.03823428  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  933  ; KL:  0.034707695  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  934  ; KL:  0.055195823  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  935  ; KL:  0.049314488  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  936  ; KL:  0.058580257  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  937  ; KL:  0.11372181  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  938  ; KL:  0.14693043  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  939  ; KL:  0.07026886  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  940  ; KL:  0.12485148  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  941  ; KL:  0.10062718  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  942  ; KL:  0.08609193  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  943  ; KL:  0.043114  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  944  ; KL:  0.039835542  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  945  ; KL:  0.061118856  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  946  ; KL:  0.049422063  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  947  ; KL:  0.056219947  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  948  ; KL:  0.06985302  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  949  ; KL:  0.06833401  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  950  ; KL:  0.054148942  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  951  ; KL:  0.06355979  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  952  ; KL:  0.031255417  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  953  ; KL:  0.052873235  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  954  ; KL:  0.040083475  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  955  ; KL:  0.051404223  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  956  ; KL:  0.0682485  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  957  ; KL:  0.09022636  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  958  ; KL:  0.079594545  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  959  ; KL:  0.052706875  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  960  ; KL:  0.03640149  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  961  ; KL:  0.024062727  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  962  ; KL:  0.048398733  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  963  ; KL:  0.06248601  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  964  ; KL:  0.054886926  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  965  ; KL:  0.057487827  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  966  ; KL:  0.025629824  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  967  ; KL:  0.04316827  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  968  ; KL:  0.035320397  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  969  ; KL:  0.038880534  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  970  ; KL:  0.049046833  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  971  ; KL:  0.022055795  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  972  ; KL:  0.08634927  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  973  ; KL:  0.057080843  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  974  ; KL:  0.031696305  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  975  ; KL:  0.065785825  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  976  ; KL:  0.023156412  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  977  ; KL:  0.023207119  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  978  ; KL:  0.040208604  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  979  ; KL:  0.052670125  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  980  ; KL:  0.04916541  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  981  ; KL:  0.04341777  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  982  ; KL:  0.043153442  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  983  ; KL:  0.030303404  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  984  ; KL:  0.04800763  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  985  ; KL:  0.047697693  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  986  ; KL:  0.037697207  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  987  ; KL:  0.04633134  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  988  ; KL:  0.045357063  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  989  ; KL:  0.03961991  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  990  ; KL:  0.025149161  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  991  ; KL:  0.02438853  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  992  ; KL:  0.032047242  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  993  ; KL:  0.014609278  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  994  ; KL:  0.024296569  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  995  ; KL:  0.022250557  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  996  ; KL:  0.029829485  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  997  ; KL:  0.03003899  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  998  ; KL:  0.032943767  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework
# epoch:  999  ; KL:  0.021076562  ; LR:  0.001  ; MR:  1.0
# Collection
# Tapework

# %%
test_env = gym.make('CartPole-v1', render_mode='human')
#test_env = gym.make('CartPole-v1', render_mode='human')

# %%
obs, inf = test_env.reset()

# %%
for i in range(1000):
    qs = pi(tf.expand_dims(obs, 0))
    act = [np.argmax(subspace) for subspace in qs[0]]
    obs, reward, terminated, _, _ = test_env.step(act[0])
    if(terminated):
        obs, _ = test_env.reset()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
